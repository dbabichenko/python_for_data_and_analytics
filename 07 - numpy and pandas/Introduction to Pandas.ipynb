# %% [markdown]
# **Introduction to Pandas**
#
# Pandas is a Python package that makes importing and analyzing data much easier. Pandas builds on packages like NumPy and matplotlib to give us a single, convenient, place to do most of your data analysis and visualization work.
#
# Parts of this tutorial are adapted from https://www.dataquest.io/blog/pandas-python-tutorial/

# %%
import pandas as pd

# %%
# Pandas uses a DataFrame data structure as a way to represent and work with tabular data. 
df = pd.read_csv("diabetes.csv")

# %%
# Once we read in a DataFrame, Pandas gives us two functions that make it fast to print out and review the data.
# pandas.DataFrame.head -- prints the first N rows of a DataFrame. By default 5.
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
# pandas.DataFrame.tail -- prints the last N rows of a DataFrame. By default 5.
df.tail()
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb location  age  gender  \
# 398  41506  296.0       369  46.0    6.4  16.110001   Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000   Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000   Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000   Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN   Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  waist   hip
# 398    69.0   173.0  medium  138.0   94.0   35.0  39.0
# 399    63.0   154.0  medium  140.0  100.0   32.0  43.0
# 400    69.0   167.0   small  120.0   70.0   33.0  40.0
# 401    63.0   197.0  medium  120.0   78.0   41.0  48.0
# 402    64.0   220.0  medium  100.0   72.0   49.0  58.0

# %%
# Randomly selects N rows from a dataframe
df.sample(10)
# Out:
#         id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  \
# 96    4786  241.0        86  63.0    3.8   4.79      Louisa   41  female
# 80    4517  217.0        88  40.0    5.4   4.84  Buckingham   34    male
# 125  10001  132.0        99  34.0    3.9   4.01  Buckingham   21  female
# 282  20279  147.0        78  42.0    3.5   4.67  Buckingham   23  female
# 293  20312  255.0       100  34.0    7.5   6.06      Louisa   64    male
# 218  15814  198.0       118  46.0    4.3   4.44  Buckingham   68  female
# 42    1323  225.0        83  42.0    5.4   4.38  Buckingham   36    male
# 234  17752  207.0       187  46.0    4.5   8.57      Louisa   44  female
# 111   4818  283.0        83  74.0    3.8   4.22      Louisa   26    male
# 148  12772  269.0        73  34.0    7.9   5.37  Buckingham   41  female
#
#      height  weight   frame  bp.1s  bp.1d  waist   hip
# 96     59.0   139.0  medium  112.0   72.0   29.0  39.0
# 80     73.0   219.0  medium  145.0  100.0   41.0  42.0
# 125    65.0   169.0   large  112.0   62.0   39.0  43.0
# 282    61.0   185.0     NaN  127.0   71.0   43.0  47.0
# 293    68.0   227.0  medium  134.0   74.0   44.0  47.0
# 218    63.0   124.0  medium  130.0   70.0   32.0  38.0
# 42     67.0   192.0   large  149.0   89.0   40.0  42.0
# 234    67.0   201.0   large  150.0   74.0   46.0  49.0
# 111    72.0   227.0   large  158.0  104.0   41.0  44.0
# 148    62.0   160.0  medium  126.0   90.0   39.0  41.0

# %%
# We can also access the pandas.DataFrame.shape property to see row many rows and columns are in a data frame:
df.shape
# Out:
# (403, 16)

# %%
# Indexing DataFrames with Pandas
# Above, we used the head() function to print the first 5 rows of reviews. 
# We could accomplish the same thing using the pandas.DataFrame.iloc function. 
# The iloc method allows us to retrieve rows and columns by position, 
# similar to how we did it with numpy 2-dimensional arrays. 

#The below code will do the same thing as df.head():

df.iloc[0:5,:]
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
# the first 5 rows, and all of the columns for those rows.
df.iloc[:5,:]
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.iloc[:,:] # the entire DataFrame.
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  waist   hip
# 0      62.0   121.0  medium  118.0   59.0   29.0  38.0
# 1      64.0   218.0   large  112.0   68.0   46.0  48.0
# 2      61.0   256.0   large  190.0   92.0   49.0  57.0
# 3      67.0   119.0   large  110.0   50.0   33.0  38.0
# 4      68.0   183.0  medium  138.0   80.0   44.0  41.0
# ..      ...     ...     ...    ...    ...    ...   ...
# 398    69.0   173.0  medium  138.0   94.0   35.0  39.0
# 399    63.0   154.0  medium  140.0  100.0   32.0  43.0
# 400    69.0   167.0   small  120.0   70.0   33.0  40.0
# 401    63.0   197.0  medium  120.0   78.0   41.0  48.0
# 402    64.0   220.0  medium  100.0   72.0   49.0  58.0
#
# [403 rows x 16 columns]

# %%
# Here are some indexing examples, along with the results:



df.iloc[5:,5:] # rows from position 5 onwards, and columns from position 5 onwards.
df.iloc[:,0] # the first column, and all of the rows for the column.
df.iloc[9,:] # the 10th row, and all of the columns for that row.
# Out:
# id                1022
# chol               263
# stab.glu            89
# hdl                 40
# ratio              6.6
# glyhb             5.78
# location    Buckingham
# age                 55
# gender          female
# height              63
# weight             202
# frame            small
# bp.1s              108
# bp.1d               72
# waist               45
# hip                 50
# Name: 9, dtype: object

# %%
# Now that we know how to index by position, let's remove the first column (patient id), 
# which doesn't have any useful information:

df = df.iloc[:,1:]
df.head()
# Out:
#     chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
# A major advantage of Pandas over NumPy is that each of the columns and rows has a label. 
# Working with column positions makes it difficult to keep track of which number corresponds to which column.
# We can work with labels using the pandas.DataFrame.loc function will allow us 
# to find rows and columns using labels instead of positions.

df.loc[:5, 'hdl']
# Out:
# 0    56.0
# 1    24.0
# 2    37.0
# 3    12.0
# 4    28.0
# 5    69.0
# Name: hdl, dtype: float64

# %%
# We can also specify more than one column at a time by passing in a list:
df.loc[:5,["hdl", "ratio", "weight"]]
# Out:
#     hdl  ratio  weight
# 0  56.0    3.6   121.0
# 1  24.0    6.9   218.0
# 2  37.0    6.2   256.0
# 3  12.0    6.5   119.0
# 4  28.0    8.9   183.0
# 5  69.0    3.6   190.0

# %%
# There's an even easier way to retrieve a whole column. 
# We can just specify the column name in square brackets, like with a dictionary:
df["weight"]
# Out:
# 0      121.0
# 1      218.0
# 2      256.0
# 3      119.0
# 4      183.0
# 5      190.0
# 6      191.0
# 7      170.0
# 8      166.0
# 9      202.0
# 10     156.0
# 11     195.0
# 12     170.0
# 13     165.0
# 14     183.0
# 15     157.0
# 16     183.0
# 17     159.0
# 18     126.0
# 19     196.0
# 20     178.0
# 21     230.0
# 22     288.0
# 23     185.0
# 24     113.0
# 25     118.0
# 26     252.0
# 27     100.0
# 28     145.0
# 29     189.0
#        ...
# 373    170.0
# 374    157.0
# 375    129.0
# 376    211.0
# 377    189.0
# 378    120.0
# 379    121.0
# 380    120.0
# 381    169.0
# 382    186.0
# 383    262.0
# 384    222.0
# 385    222.0
# 386    179.0
# 387    224.0
# 388    165.0
# 389    185.0
# 390    147.0
# 391    177.0
# 392    145.0
# 393    146.0
# 394    154.0
# 395    136.0
# 396    168.0
# 397    115.0
# 398    173.0
# 399    154.0
# 400    167.0
# 401    197.0
# 402    220.0
# Name: weight, Length: 403, dtype: float64

# %%
# We can also use lists of columns with this method:

df[["hdl", "ratio", "weight"]]
# Out:
#       hdl  ratio  weight
# 0    56.0    3.6   121.0
# 1    24.0    6.9   218.0
# 2    37.0    6.2   256.0
# 3    12.0    6.5   119.0
# 4    28.0    8.9   183.0
# ..    ...    ...     ...
# 398  46.0    6.4   173.0
# 399  54.0    5.3   154.0
# 400  38.0    5.1   167.0
# 401  52.0    3.8   197.0
# 402  79.0    2.0   220.0
#
# [403 rows x 3 columns]
