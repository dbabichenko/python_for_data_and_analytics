# %% [markdown]
# * https://github.com/mubaris/friendly-fortnight
# * https://mubaris.com/2017/10/01/kmeans-clustering-in-python/

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)

# %%
# Creating a sample dataset with 4 clusters
X, y = make_blobs(n_samples=10000, n_features=3, centers=3)
X
# Out:
# array([[ 2.24177821,  3.80634273, -4.93800232],
#        [ 5.03116009, 11.11780649,  2.65080564],
#        [-7.30193652, -3.70151103, -6.87316413],
#        ...,
#        [-5.6881256 , -1.74694317, -8.25436757],
#        [ 3.41399645,  3.03474782, -4.56452224],
#        [ 3.00418957,  3.45429921, -5.40154095]])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=3)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
print(C)
# Out:
# [[ 3.83630214  3.50577182 -4.45497232]
#  [-8.11733731 -3.55435802 -6.51536913]
#  [ 5.26428474  9.81616644  1.92478449]]

# %%
print(labels[:10])
# Out:
# [0 2 1 1 2 1 1 1 0 2]

# %%
import pandas as pd
df = pd.DataFrame(X)
df = pd.concat([df.reset_index(), pd.Series(labels)], axis = 1)
df.head()
# Out:
#    index         0          1         2  0
# 0      0  2.241778   3.806343 -4.938002  0
# 1      1  5.031160  11.117806  2.650806  2
# 2      2 -7.301937  -3.701511 -6.873164  1
# 3      3 -6.611338  -4.578309 -6.714630  1
# 4      4  3.705324   9.719043  1.917970  2

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#000000', s=10000)
