# %% [markdown]
# * https://github.com/mubaris/friendly-fortnight
# * https://mubaris.com/2017/10/01/kmeans-clustering-in-python/

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)

# %%
# Creating a sample dataset with 4 clusters
X, y = make_blobs(n_samples=10000, n_features=3, centers=4)
X
# Out:
# array([[-0.6306953 ,  5.15851518,  7.79012707],
#        [-9.00227953,  7.27784007, -2.98080523],
#        [-1.69413938, -0.09172205, -0.11172203],
#        ...,
#        [-2.44165408,  2.52141665,  0.09393003],
#        [ 1.41172483,  4.65746853,  8.17968155],
#        [ 2.67800467,  1.91169586, -3.86072656]])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=4)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
print(C)
# Out:
# [[-1.56821894 -7.75896034 -8.52584171]
#  [-8.75432028  6.60703264 -7.97398001]
#  [ 2.2665336   6.08688074  7.38210252]
#  [ 5.18150273  9.80309684 -9.82441391]]

# %%
import pandas as pd
df = pd.DataFrame(X)
df = pd.concat([df, pd.Series(labels)], axis = 1)
df.head()
# Out:
#           0         1         2  0
# 0 -8.464632  7.255040 -6.656615  1
# 1 -7.661014  5.470615 -7.033162  1
# 2  5.977603  9.799755 -8.191414  3
# 3 -0.669741 -7.765248 -8.094926  0
# 4 -2.389915 -8.819150 -8.065609  0

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)
