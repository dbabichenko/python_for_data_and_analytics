# %% [markdown]
# * TARGET_deathRate: Dependent variable. Mean per capita (100,000) cancer mortalities(a)
# * avgAnnCount: Mean number of reported cases of cancer diagnosed annually(a)
# * avgDeathsPerYear: Mean number of reported mortalities due to cancer(a)
# * incidenceRate: Mean per capita (100,000) cancer diagoses(a)
# * medianIncome: Median income per county (b)
# * popEst2015: Population of county (b)
# * povertyPercent: Percent of populace in poverty (b)
# * studyPerCap: Per capita number of cancer-related clinical trials per county (a)
# * binnedInc: Median income per capita binned by decile (b)
# * MedianAge: Median age of county residents (b)
# * MedianAgeMale: Median age of male county residents (b)
# * MedianAgeFemale: Median age of female county residents (b)
# * Geography: County name (b)
# * AvgHouseholdSize: Mean household size of county (b)
# * PercentMarried: Percent of county residents who are married (b)
# * PctNoHS18_24: Percent of county residents ages 18-24 highest education attained: less than high school (b)
# * PctHS18_24: Percent of county residents ages 18-24 highest education attained: high school diploma (b)
# * PctSomeCol18_24: Percent of county residents ages 18-24 highest education attained: some college (b)
# * PctBachDeg18_24: Percent of county residents ages 18-24 highest education attained: bachelor's degree (b)
# * PctHS25_Over: Percent of county residents ages 25 and over highest education attained: high school diploma (b)
# * PctBachDeg25_Over: Percent of county residents ages 25 and over highest education attained: bachelor's degree (b)
# * PctEmployed16_Over: Percent of county residents ages 16 and over employed (b)
# * PctUnemployed16_Over: Percent of county residents ages 16 and over unemployed (b)
# * PctPrivateCoverage: Percent of county residents with private health coverage (b)
# * PctPrivateCoverageAlone: Percent of county residents with private health coverage alone (no public assistance) (b)
# * PctEmpPrivCoverage: Percent of county residents with employee-provided private health coverage (b)
# * PctPublicCoverage: Percent of county residents with government-provided health coverage (b)
# * PctPubliceCoverageAlone: Percent of county residents with government-provided health coverage alone (b)
# * PctWhite: Percent of county residents who identify as White (b)
# * PctBlack: Percent of county residents who identify as Black (b)
# * PctAsian: Percent of county residents who identify as Asian (b)
# * PctOtherRace: Percent of county residents who identify in a category which is not White, Black, or Asian (b)
# * PctMarriedHouseholds: Percent of married households (b)
# * BirthRate: Number of live births relative to number of women in county (b)

# %%
import pandas as pd
import numpy as np
from itertools import combinations
from itertools import permutations

# %%
# Let's start by examining the dataset
df = pd.read_excel('cancer_reg.xlsx')
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
#    ...  PctPrivateCoverageAlone  PctEmpPrivCoverage PctPublicCoverage  \
# 0  ...                      NaN                41.6              32.9
# 1  ...                     53.8                43.6              31.1
# 2  ...                     43.5                34.9              42.1
# 3  ...                     40.3                35.0              45.3
# 4  ...                     43.9                35.1              44.0
#
#    PctPublicCoverageAlone   PctWhite  PctBlack  PctAsian  PctOtherRace  \
# 0                    14.0  81.780529  2.594728  4.821857      1.843479
# 1                    15.3  89.228509  0.969102  2.246233      3.741352
# 2                    21.1  90.922190  0.739673  0.465898      2.747358
# 3                    25.0  91.744686  0.782626  1.161359      1.362643
# 4                    22.7  94.104024  0.270192  0.665830      0.492135
#
#    PctMarriedHouseholds  BirthRate
# 0             52.856076   6.118831
# 1             45.372500   4.333096
# 2             54.444868   3.729488
# 3             51.021514   4.603841
# 4             54.027460   6.796657
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (3047, 34)

# %%
df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# binnedInc                   object
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# PctWhite                   float64
# PctBlack                   float64
# PctAsian                   float64
# PctOtherRace               float64
# PctMarriedHouseholds       float64
# BirthRate                  float64
# dtype: object

# %%
df['Geography'].value_counts()
# Out:
# Monroe County, Missouri          1
# Hancock County, West Virginia    1
# Delta County, Michigan           1
# Jersey County, Illinois          1
# Lawrence County, Ohio            1
#                                 ..
# Rappahannock County, Virginia    1
# Fayette County, Indiana          1
# Charles City County, Virginia    1
# Franklin County, Idaho           1
# Hancock County, Kentucky         1
# Name: Geography, Length: 3047, dtype: int64

# %%
def extract_state(geography):
    arr = geography.split(',')
    return arr[-1].strip()

# %%
df['State'] = df['Geography'].apply(extract_state)

# %%
df.drop(['binnedInc','Geography'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap  MedianAge  MedianAgeMale  ...  \
# 0      260131            11.2   499.748204       39.3           36.9  ...
# 1       43269            18.6    23.111234       33.0           32.2  ...
# 2       21026            14.6    47.560164       45.0           44.0  ...
# 3       75882            17.1   342.637253       42.8           42.2  ...
# 4       10321            12.5     0.000000       48.3           47.8  ...
#
#    PctEmpPrivCoverage  PctPublicCoverage  PctPublicCoverageAlone   PctWhite  \
# 0                41.6               32.9                    14.0  81.780529
# 1                43.6               31.1                    15.3  89.228509
# 2                34.9               42.1                    21.1  90.922190
# 3                35.0               45.3                    25.0  91.744686
# 4                35.1               44.0                    22.7  94.104024
#
#    PctBlack  PctAsian  PctOtherRace  PctMarriedHouseholds  BirthRate  \
# 0  2.594728  4.821857      1.843479             52.856076   6.118831
# 1  0.969102  2.246233      3.741352             45.372500   4.333096
# 2  0.739673  0.465898      2.747358             54.444868   3.729488
# 3  0.782626  1.161359      1.362643             51.021514   4.603841
# 4  0.270192  0.665830      0.492135             54.027460   6.796657
#
#         State
# 0  Washington
# 1  Washington
# 2  Washington
# 3  Washington
# 4  Washington
#
# [5 rows x 33 columns]

# %%
from sklearn.preprocessing import LabelEncoder
def label_encode(df, columns):
    for col in columns:
        le = LabelEncoder()
        col_values_unique = list(df[col].unique())
        le_fitted = le.fit(col_values_unique)
 
        col_values = list(df[col].values)
        #le.classes_
        col_values_transformed = le.transform(col_values)
        df[col] = col_values_transformed

# %%
X = df.drop('TARGET_deathRate', axis=1)
label_encode(X, ['State'])
y = df[['TARGET_deathRate']]

# %%
X.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# PctWhite                   float64
# PctBlack                   float64
# PctAsian                   float64
# PctOtherRace               float64
# PctMarriedHouseholds       float64
# BirthRate                  float64
# State                        int64
# dtype: object

# %%
comb_list = []
for i in range(6):
    comb_list = comb_list + list(combinations(X.columns, i))
    
comb_list
# Out:
# [(),
#  ('avgAnnCount',),
#  ('avgDeathsPerYear',),
#  ('incidenceRate',),
#  ('medIncome',),
#  ('popEst2015',),
#  ('povertyPercent',),
#  ('studyPerCap',),
#  ('MedianAge',),
#  ('MedianAgeMale',),
#  ('MedianAgeFemale',),
#  ('AvgHouseholdSize',),
#  ('PercentMarried',),
#  ('PctNoHS18_24',),
#  ('PctHS18_24',),
#  ('PctSomeCol18_24',),
#  ('PctBachDeg18_24',),
#  ('PctHS25_Over',),
#  ('PctBachDeg25_Over',),
#  ('PctEmployed16_Over',),
#  ('PctUnemployed16_Over',),
#  ('PctPrivateCoverage',),
#  ('PctPrivateCoverageAlone',),
#  ('PctEmpPrivCoverage',),
#  ('PctPublicCoverage',),
#  ('PctPublicCoverageAlone',),
#  ('PctWhite',),
#  ('PctBlack',),
#  ('PctAsian',),
#  ('PctOtherRace',),
#  ('PctMarriedHouseholds',),
#  ('BirthRate',),
#  ('State',),
#  ('avgAnnCount', 'avgDeathsPerYear'),
#  ('avgAnnCount', 'incidenceRate'),
#  ('avgAnnCount', 'medIncome'),
#  ('avgAnnCount', 'popEst2015'),
#  ('avgAnnCount', 'povertyPercent'),
#  ('avgAnnCount', 'studyPerCap'),
#  ('avgAnnCount', 'MedianAge'),
#  ('avgAnnCount', 'MedianAgeMale'),
#  ('avgAnnCount', 'MedianAgeFemale'),
#  ('avgAnnCount', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'PercentMarried'),
#  ('avgAnnCount', 'PctNoHS18_24'),
#  ('avgAnnCount', 'PctHS18_24'),
#  ('avgAnnCount', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'PctHS25_Over'),
#  ('avgAnnCount', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctWhite'),
#  ('avgAnnCount', 'PctBlack'),
#  ('avgAnnCount', 'PctAsian'),
#  ('avgAnnCount', 'PctOtherRace'),
#  ('avgAnnCount', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'BirthRate'),
#  ('avgAnnCount', 'State'),
#  ('avgDeathsPerYear', 'incidenceRate'),
#  ('avgDeathsPerYear', 'medIncome'),
#  ('avgDeathsPerYear', 'popEst2015'),
#  ('avgDeathsPerYear', 'povertyPercent'),
#  ('avgDeathsPerYear', 'studyPerCap'),
#  ('avgDeathsPerYear', 'MedianAge'),
#  ('avgDeathsPerYear', 'MedianAgeMale'),
#  ('avgDeathsPerYear', 'MedianAgeFemale'),
#  ('avgDeathsPerYear', 'AvgHouseholdSize'),
#  ('avgDeathsPerYear', 'PercentMarried'),
#  ('avgDeathsPerYear', 'PctNoHS18_24'),
#  ('avgDeathsPerYear', 'PctHS18_24'),
#  ('avgDeathsPerYear', 'PctSomeCol18_24'),
#  ('avgDeathsPerYear', 'PctBachDeg18_24'),
#  ('avgDeathsPerYear', 'PctHS25_Over'),
#  ('avgDeathsPerYear', 'PctBachDeg25_Over'),
#  ('avgDeathsPerYear', 'PctEmployed16_Over'),
#  ('avgDeathsPerYear', 'PctUnemployed16_Over'),
#  ('avgDeathsPerYear', 'PctPrivateCoverage'),
#  ('avgDeathsPerYear', 'PctPrivateCoverageAlone'),
#  ('avgDeathsPerYear', 'PctEmpPrivCoverage'),
#  ('avgDeathsPerYear', 'PctPublicCoverage'),
#  ('avgDeathsPerYear', 'PctPublicCoverageAlone'),
#  ('avgDeathsPerYear', 'PctWhite'),
#  ('avgDeathsPerYear', 'PctBlack'),
#  ('avgDeathsPerYear', 'PctAsian'),
#  ('avgDeathsPerYear', 'PctOtherRace'),
#  ('avgDeathsPerYear', 'PctMarriedHouseholds'),
#  ('avgDeathsPerYear', 'BirthRate'),
#  ('avgDeathsPerYear', 'State'),
#  ('incidenceRate', 'medIncome'),
#  ('incidenceRate', 'popEst2015'),
#  ('incidenceRate', 'povertyPercent'),
#  ('incidenceRate', 'studyPerCap'),
#  ('incidenceRate', 'MedianAge'),
#  ('incidenceRate', 'MedianAgeMale'),
#  ('incidenceRate', 'MedianAgeFemale'),
#  ('incidenceRate', 'AvgHouseholdSize'),
#  ('incidenceRate', 'PercentMarried'),
#  ('incidenceRate', 'PctNoHS18_24'),
#  ('incidenceRate', 'PctHS18_24'),
#  ('incidenceRate', 'PctSomeCol18_24'),
#  ('incidenceRate', 'PctBachDeg18_24'),
#  ('incidenceRate', 'PctHS25_Over'),
#  ('incidenceRate', 'PctBachDeg25_Over'),
#  ('incidenceRate', 'PctEmployed16_Over'),
#  ('incidenceRate', 'PctUnemployed16_Over'),
#  ('incidenceRate', 'PctPrivateCoverage'),
#  ('incidenceRate', 'PctPrivateCoverageAlone'),
#  ('incidenceRate', 'PctEmpPrivCoverage'),
#  ('incidenceRate', 'PctPublicCoverage'),
#  ('incidenceRate', 'PctPublicCoverageAlone'),
#  ('incidenceRate', 'PctWhite'),
#  ('incidenceRate', 'PctBlack'),
#  ('incidenceRate', 'PctAsian'),
#  ('incidenceRate', 'PctOtherRace'),
#  ('incidenceRate', 'PctMarriedHouseholds'),
#  ('incidenceRate', 'BirthRate'),
#  ('incidenceRate', 'State'),
#  ('medIncome', 'popEst2015'),
#  ('medIncome', 'povertyPercent'),
#  ('medIncome', 'studyPerCap'),
#  ('medIncome', 'MedianAge'),
#  ('medIncome', 'MedianAgeMale'),
#  ('medIncome', 'MedianAgeFemale'),
#  ('medIncome', 'AvgHouseholdSize'),
#  ('medIncome', 'PercentMarried'),
#  ('medIncome', 'PctNoHS18_24'),
#  ('medIncome', 'PctHS18_24'),
#  ('medIncome', 'PctSomeCol18_24'),
#  ('medIncome', 'PctBachDeg18_24'),
#  ('medIncome', 'PctHS25_Over'),
#  ('medIncome', 'PctBachDeg25_Over'),
#  ('medIncome', 'PctEmployed16_Over'),
#  ('medIncome', 'PctUnemployed16_Over'),
#  ('medIncome', 'PctPrivateCoverage'),
#  ('medIncome', 'PctPrivateCoverageAlone'),
#  ('medIncome', 'PctEmpPrivCoverage'),
#  ('medIncome', 'PctPublicCoverage'),
#  ('medIncome', 'PctPublicCoverageAlone'),
#  ('medIncome', 'PctWhite'),
#  ('medIncome', 'PctBlack'),
#  ('medIncome', 'PctAsian'),
#  ('medIncome', 'PctOtherRace'),
#  ('medIncome', 'PctMarriedHouseholds'),
#  ('medIncome', 'BirthRate'),
#  ('medIncome', 'State'),
#  ('popEst2015', 'povertyPercent'),
#  ('popEst2015', 'studyPerCap'),
#  ('popEst2015', 'MedianAge'),
#  ('popEst2015', 'MedianAgeMale'),
#  ('popEst2015', 'MedianAgeFemale'),
#  ('popEst2015', 'AvgHouseholdSize'),
#  ('popEst2015', 'PercentMarried'),
#  ('popEst2015', 'PctNoHS18_24'),
#  ('popEst2015', 'PctHS18_24'),
#  ('popEst2015', 'PctSomeCol18_24'),
#  ('popEst2015', 'PctBachDeg18_24'),
#  ('popEst2015', 'PctHS25_Over'),
#  ('popEst2015', 'PctBachDeg25_Over'),
#  ('popEst2015', 'PctEmployed16_Over'),
#  ('popEst2015', 'PctUnemployed16_Over'),
#  ('popEst2015', 'PctPrivateCoverage'),
#  ('popEst2015', 'PctPrivateCoverageAlone'),
#  ('popEst2015', 'PctEmpPrivCoverage'),
#  ('popEst2015', 'PctPublicCoverage'),
#  ('popEst2015', 'PctPublicCoverageAlone'),
#  ('popEst2015', 'PctWhite'),
#  ('popEst2015', 'PctBlack'),
#  ('popEst2015', 'PctAsian'),
#  ('popEst2015', 'PctOtherRace'),
#  ('popEst2015', 'PctMarriedHouseholds'),
#  ('popEst2015', 'BirthRate'),
#  ('popEst2015', 'State'),
#  ('povertyPercent', 'studyPerCap'),
#  ('povertyPercent', 'MedianAge'),
#  ('povertyPercent', 'MedianAgeMale'),
#  ('povertyPercent', 'MedianAgeFemale'),
#  ('povertyPercent', 'AvgHouseholdSize'),
#  ('povertyPercent', 'PercentMarried'),
#  ('povertyPercent', 'PctNoHS18_24'),
#  ('povertyPercent', 'PctHS18_24'),
#  ('povertyPercent', 'PctSomeCol18_24'),
#  ('povertyPercent', 'PctBachDeg18_24'),
#  ('povertyPercent', 'PctHS25_Over'),
#  ('povertyPercent', 'PctBachDeg25_Over'),
#  ('povertyPercent', 'PctEmployed16_Over'),
#  ('povertyPercent', 'PctUnemployed16_Over'),
#  ('povertyPercent', 'PctPrivateCoverage'),
#  ('povertyPercent', 'PctPrivateCoverageAlone'),
#  ('povertyPercent', 'PctEmpPrivCoverage'),
#  ('povertyPercent', 'PctPublicCoverage'),
#  ('povertyPercent', 'PctPublicCoverageAlone'),
#  ('povertyPercent', 'PctWhite'),
#  ('povertyPercent', 'PctBlack'),
#  ('povertyPercent', 'PctAsian'),
#  ('povertyPercent', 'PctOtherRace'),
#  ('povertyPercent', 'PctMarriedHouseholds'),
#  ('povertyPercent', 'BirthRate'),
#  ('povertyPercent', 'State'),
#  ('studyPerCap', 'MedianAge'),
#  ('studyPerCap', 'MedianAgeMale'),
#  ('studyPerCap', 'MedianAgeFemale'),
#  ('studyPerCap', 'AvgHouseholdSize'),
#  ('studyPerCap', 'PercentMarried'),
#  ('studyPerCap', 'PctNoHS18_24'),
#  ('studyPerCap', 'PctHS18_24'),
#  ('studyPerCap', 'PctSomeCol18_24'),
#  ('studyPerCap', 'PctBachDeg18_24'),
#  ('studyPerCap', 'PctHS25_Over'),
#  ('studyPerCap', 'PctBachDeg25_Over'),
#  ('studyPerCap', 'PctEmployed16_Over'),
#  ('studyPerCap', 'PctUnemployed16_Over'),
#  ('studyPerCap', 'PctPrivateCoverage'),
#  ('studyPerCap', 'PctPrivateCoverageAlone'),
#  ('studyPerCap', 'PctEmpPrivCoverage'),
#  ('studyPerCap', 'PctPublicCoverage'),
#  ('studyPerCap', 'PctPublicCoverageAlone'),
#  ('studyPerCap', 'PctWhite'),
#  ('studyPerCap', 'PctBlack'),
#  ('studyPerCap', 'PctAsian'),
#  ('studyPerCap', 'PctOtherRace'),
#  ('studyPerCap', 'PctMarriedHouseholds'),
#  ('studyPerCap', 'BirthRate'),
#  ('studyPerCap', 'State'),
#  ('MedianAge', 'MedianAgeMale'),
#  ('MedianAge', 'MedianAgeFemale'),
#  ('MedianAge', 'AvgHouseholdSize'),
#  ('MedianAge', 'PercentMarried'),
#  ('MedianAge', 'PctNoHS18_24'),
#  ('MedianAge', 'PctHS18_24'),
#  ('MedianAge', 'PctSomeCol18_24'),
#  ('MedianAge', 'PctBachDeg18_24'),
#  ('MedianAge', 'PctHS25_Over'),
#  ('MedianAge', 'PctBachDeg25_Over'),
#  ('MedianAge', 'PctEmployed16_Over'),
#  ('MedianAge', 'PctUnemployed16_Over'),
#  ('MedianAge', 'PctPrivateCoverage'),
#  ('MedianAge', 'PctPrivateCoverageAlone'),
#  ('MedianAge', 'PctEmpPrivCoverage'),
#  ('MedianAge', 'PctPublicCoverage'),
#  ('MedianAge', 'PctPublicCoverageAlone'),
#  ('MedianAge', 'PctWhite'),
#  ('MedianAge', 'PctBlack'),
#  ('MedianAge', 'PctAsian'),
#  ('MedianAge', 'PctOtherRace'),
#  ('MedianAge', 'PctMarriedHouseholds'),
#  ('MedianAge', 'BirthRate'),
#  ('MedianAge', 'State'),
#  ('MedianAgeMale', 'MedianAgeFemale'),
#  ('MedianAgeMale', 'AvgHouseholdSize'),
#  ('MedianAgeMale', 'PercentMarried'),
#  ('MedianAgeMale', 'PctNoHS18_24'),
#  ('MedianAgeMale', 'PctHS18_24'),
#  ('MedianAgeMale', 'PctSomeCol18_24'),
#  ('MedianAgeMale', 'PctBachDeg18_24'),
#  ('MedianAgeMale', 'PctHS25_Over'),
#  ('MedianAgeMale', 'PctBachDeg25_Over'),
#  ('MedianAgeMale', 'PctEmployed16_Over'),
#  ('MedianAgeMale', 'PctUnemployed16_Over'),
#  ('MedianAgeMale', 'PctPrivateCoverage'),
#  ('MedianAgeMale', 'PctPrivateCoverageAlone'),
#  ('MedianAgeMale', 'PctEmpPrivCoverage'),
#  ('MedianAgeMale', 'PctPublicCoverage'),
#  ('MedianAgeMale', 'PctPublicCoverageAlone'),
#  ('MedianAgeMale', 'PctWhite'),
#  ('MedianAgeMale', 'PctBlack'),
#  ('MedianAgeMale', 'PctAsian'),
#  ('MedianAgeMale', 'PctOtherRace'),
#  ('MedianAgeMale', 'PctMarriedHouseholds'),
#  ('MedianAgeMale', 'BirthRate'),
#  ('MedianAgeMale', 'State'),
#  ('MedianAgeFemale', 'AvgHouseholdSize'),
#  ('MedianAgeFemale', 'PercentMarried'),
#  ('MedianAgeFemale', 'PctNoHS18_24'),
#  ('MedianAgeFemale', 'PctHS18_24'),
#  ('MedianAgeFemale', 'PctSomeCol18_24'),
#  ('MedianAgeFemale', 'PctBachDeg18_24'),
#  ('MedianAgeFemale', 'PctHS25_Over'),
#  ('MedianAgeFemale', 'PctBachDeg25_Over'),
#  ('MedianAgeFemale', 'PctEmployed16_Over'),
#  ('MedianAgeFemale', 'PctUnemployed16_Over'),
#  ('MedianAgeFemale', 'PctPrivateCoverage'),
#  ('MedianAgeFemale', 'PctPrivateCoverageAlone'),
#  ('MedianAgeFemale', 'PctEmpPrivCoverage'),
#  ('MedianAgeFemale', 'PctPublicCoverage'),
#  ('MedianAgeFemale', 'PctPublicCoverageAlone'),
#  ('MedianAgeFemale', 'PctWhite'),
#  ('MedianAgeFemale', 'PctBlack'),
#  ('MedianAgeFemale', 'PctAsian'),
#  ('MedianAgeFemale', 'PctOtherRace'),
#  ('MedianAgeFemale', 'PctMarriedHouseholds'),
#  ('MedianAgeFemale', 'BirthRate'),
#  ('MedianAgeFemale', 'State'),
#  ('AvgHouseholdSize', 'PercentMarried'),
#  ('AvgHouseholdSize', 'PctNoHS18_24'),
#  ('AvgHouseholdSize', 'PctHS18_24'),
#  ('AvgHouseholdSize', 'PctSomeCol18_24'),
#  ('AvgHouseholdSize', 'PctBachDeg18_24'),
#  ('AvgHouseholdSize', 'PctHS25_Over'),
#  ('AvgHouseholdSize', 'PctBachDeg25_Over'),
#  ('AvgHouseholdSize', 'PctEmployed16_Over'),
#  ('AvgHouseholdSize', 'PctUnemployed16_Over'),
#  ('AvgHouseholdSize', 'PctPrivateCoverage'),
#  ('AvgHouseholdSize', 'PctPrivateCoverageAlone'),
#  ('AvgHouseholdSize', 'PctEmpPrivCoverage'),
#  ('AvgHouseholdSize', 'PctPublicCoverage'),
#  ('AvgHouseholdSize', 'PctPublicCoverageAlone'),
#  ('AvgHouseholdSize', 'PctWhite'),
#  ('AvgHouseholdSize', 'PctBlack'),
#  ('AvgHouseholdSize', 'PctAsian'),
#  ('AvgHouseholdSize', 'PctOtherRace'),
#  ('AvgHouseholdSize', 'PctMarriedHouseholds'),
#  ('AvgHouseholdSize', 'BirthRate'),
#  ('AvgHouseholdSize', 'State'),
#  ('PercentMarried', 'PctNoHS18_24'),
#  ('PercentMarried', 'PctHS18_24'),
#  ('PercentMarried', 'PctSomeCol18_24'),
#  ('PercentMarried', 'PctBachDeg18_24'),
#  ('PercentMarried', 'PctHS25_Over'),
#  ('PercentMarried', 'PctBachDeg25_Over'),
#  ('PercentMarried', 'PctEmployed16_Over'),
#  ('PercentMarried', 'PctUnemployed16_Over'),
#  ('PercentMarried', 'PctPrivateCoverage'),
#  ('PercentMarried', 'PctPrivateCoverageAlone'),
#  ('PercentMarried', 'PctEmpPrivCoverage'),
#  ('PercentMarried', 'PctPublicCoverage'),
#  ('PercentMarried', 'PctPublicCoverageAlone'),
#  ('PercentMarried', 'PctWhite'),
#  ('PercentMarried', 'PctBlack'),
#  ('PercentMarried', 'PctAsian'),
#  ('PercentMarried', 'PctOtherRace'),
#  ('PercentMarried', 'PctMarriedHouseholds'),
#  ('PercentMarried', 'BirthRate'),
#  ('PercentMarried', 'State'),
#  ('PctNoHS18_24', 'PctHS18_24'),
#  ('PctNoHS18_24', 'PctSomeCol18_24'),
#  ('PctNoHS18_24', 'PctBachDeg18_24'),
#  ('PctNoHS18_24', 'PctHS25_Over'),
#  ('PctNoHS18_24', 'PctBachDeg25_Over'),
#  ('PctNoHS18_24', 'PctEmployed16_Over'),
#  ('PctNoHS18_24', 'PctUnemployed16_Over'),
#  ('PctNoHS18_24', 'PctPrivateCoverage'),
#  ('PctNoHS18_24', 'PctPrivateCoverageAlone'),
#  ('PctNoHS18_24', 'PctEmpPrivCoverage'),
#  ('PctNoHS18_24', 'PctPublicCoverage'),
#  ('PctNoHS18_24', 'PctPublicCoverageAlone'),
#  ('PctNoHS18_24', 'PctWhite'),
#  ('PctNoHS18_24', 'PctBlack'),
#  ('PctNoHS18_24', 'PctAsian'),
#  ('PctNoHS18_24', 'PctOtherRace'),
#  ('PctNoHS18_24', 'PctMarriedHouseholds'),
#  ('PctNoHS18_24', 'BirthRate'),
#  ('PctNoHS18_24', 'State'),
#  ('PctHS18_24', 'PctSomeCol18_24'),
#  ('PctHS18_24', 'PctBachDeg18_24'),
#  ('PctHS18_24', 'PctHS25_Over'),
#  ('PctHS18_24', 'PctBachDeg25_Over'),
#  ('PctHS18_24', 'PctEmployed16_Over'),
#  ('PctHS18_24', 'PctUnemployed16_Over'),
#  ('PctHS18_24', 'PctPrivateCoverage'),
#  ('PctHS18_24', 'PctPrivateCoverageAlone'),
#  ('PctHS18_24', 'PctEmpPrivCoverage'),
#  ('PctHS18_24', 'PctPublicCoverage'),
#  ('PctHS18_24', 'PctPublicCoverageAlone'),
#  ('PctHS18_24', 'PctWhite'),
#  ('PctHS18_24', 'PctBlack'),
#  ('PctHS18_24', 'PctAsian'),
#  ('PctHS18_24', 'PctOtherRace'),
#  ('PctHS18_24', 'PctMarriedHouseholds'),
#  ('PctHS18_24', 'BirthRate'),
#  ('PctHS18_24', 'State'),
#  ('PctSomeCol18_24', 'PctBachDeg18_24'),
#  ('PctSomeCol18_24', 'PctHS25_Over'),
#  ('PctSomeCol18_24', 'PctBachDeg25_Over'),
#  ('PctSomeCol18_24', 'PctEmployed16_Over'),
#  ('PctSomeCol18_24', 'PctUnemployed16_Over'),
#  ('PctSomeCol18_24', 'PctPrivateCoverage'),
#  ('PctSomeCol18_24', 'PctPrivateCoverageAlone'),
#  ('PctSomeCol18_24', 'PctEmpPrivCoverage'),
#  ('PctSomeCol18_24', 'PctPublicCoverage'),
#  ('PctSomeCol18_24', 'PctPublicCoverageAlone'),
#  ('PctSomeCol18_24', 'PctWhite'),
#  ('PctSomeCol18_24', 'PctBlack'),
#  ('PctSomeCol18_24', 'PctAsian'),
#  ('PctSomeCol18_24', 'PctOtherRace'),
#  ('PctSomeCol18_24', 'PctMarriedHouseholds'),
#  ('PctSomeCol18_24', 'BirthRate'),
#  ('PctSomeCol18_24', 'State'),
#  ('PctBachDeg18_24', 'PctHS25_Over'),
#  ('PctBachDeg18_24', 'PctBachDeg25_Over'),
#  ('PctBachDeg18_24', 'PctEmployed16_Over'),
#  ('PctBachDeg18_24', 'PctUnemployed16_Over'),
#  ('PctBachDeg18_24', 'PctPrivateCoverage'),
#  ('PctBachDeg18_24', 'PctPrivateCoverageAlone'),
#  ('PctBachDeg18_24', 'PctEmpPrivCoverage'),
#  ('PctBachDeg18_24', 'PctPublicCoverage'),
#  ('PctBachDeg18_24', 'PctPublicCoverageAlone'),
#  ('PctBachDeg18_24', 'PctWhite'),
#  ('PctBachDeg18_24', 'PctBlack'),
#  ('PctBachDeg18_24', 'PctAsian'),
#  ('PctBachDeg18_24', 'PctOtherRace'),
#  ('PctBachDeg18_24', 'PctMarriedHouseholds'),
#  ('PctBachDeg18_24', 'BirthRate'),
#  ('PctBachDeg18_24', 'State'),
#  ('PctHS25_Over', 'PctBachDeg25_Over'),
#  ('PctHS25_Over', 'PctEmployed16_Over'),
#  ('PctHS25_Over', 'PctUnemployed16_Over'),
#  ('PctHS25_Over', 'PctPrivateCoverage'),
#  ('PctHS25_Over', 'PctPrivateCoverageAlone'),
#  ('PctHS25_Over', 'PctEmpPrivCoverage'),
#  ('PctHS25_Over', 'PctPublicCoverage'),
#  ('PctHS25_Over', 'PctPublicCoverageAlone'),
#  ('PctHS25_Over', 'PctWhite'),
#  ('PctHS25_Over', 'PctBlack'),
#  ('PctHS25_Over', 'PctAsian'),
#  ('PctHS25_Over', 'PctOtherRace'),
#  ('PctHS25_Over', 'PctMarriedHouseholds'),
#  ('PctHS25_Over', 'BirthRate'),
#  ('PctHS25_Over', 'State'),
#  ('PctBachDeg25_Over', 'PctEmployed16_Over'),
#  ('PctBachDeg25_Over', 'PctUnemployed16_Over'),
#  ('PctBachDeg25_Over', 'PctPrivateCoverage'),
#  ('PctBachDeg25_Over', 'PctPrivateCoverageAlone'),
#  ('PctBachDeg25_Over', 'PctEmpPrivCoverage'),
#  ('PctBachDeg25_Over', 'PctPublicCoverage'),
#  ('PctBachDeg25_Over', 'PctPublicCoverageAlone'),
#  ('PctBachDeg25_Over', 'PctWhite'),
#  ('PctBachDeg25_Over', 'PctBlack'),
#  ('PctBachDeg25_Over', 'PctAsian'),
#  ('PctBachDeg25_Over', 'PctOtherRace'),
#  ('PctBachDeg25_Over', 'PctMarriedHouseholds'),
#  ('PctBachDeg25_Over', 'BirthRate'),
#  ('PctBachDeg25_Over', 'State'),
#  ('PctEmployed16_Over', 'PctUnemployed16_Over'),
#  ('PctEmployed16_Over', 'PctPrivateCoverage'),
#  ('PctEmployed16_Over', 'PctPrivateCoverageAlone'),
#  ('PctEmployed16_Over', 'PctEmpPrivCoverage'),
#  ('PctEmployed16_Over', 'PctPublicCoverage'),
#  ('PctEmployed16_Over', 'PctPublicCoverageAlone'),
#  ('PctEmployed16_Over', 'PctWhite'),
#  ('PctEmployed16_Over', 'PctBlack'),
#  ('PctEmployed16_Over', 'PctAsian'),
#  ('PctEmployed16_Over', 'PctOtherRace'),
#  ('PctEmployed16_Over', 'PctMarriedHouseholds'),
#  ('PctEmployed16_Over', 'BirthRate'),
#  ('PctEmployed16_Over', 'State'),
#  ('PctUnemployed16_Over', 'PctPrivateCoverage'),
#  ('PctUnemployed16_Over', 'PctPrivateCoverageAlone'),
#  ('PctUnemployed16_Over', 'PctEmpPrivCoverage'),
#  ('PctUnemployed16_Over', 'PctPublicCoverage'),
#  ('PctUnemployed16_Over', 'PctPublicCoverageAlone'),
#  ('PctUnemployed16_Over', 'PctWhite'),
#  ('PctUnemployed16_Over', 'PctBlack'),
#  ('PctUnemployed16_Over', 'PctAsian'),
#  ('PctUnemployed16_Over', 'PctOtherRace'),
#  ('PctUnemployed16_Over', 'PctMarriedHouseholds'),
#  ('PctUnemployed16_Over', 'BirthRate'),
#  ('PctUnemployed16_Over', 'State'),
#  ('PctPrivateCoverage', 'PctPrivateCoverageAlone'),
#  ('PctPrivateCoverage', 'PctEmpPrivCoverage'),
#  ('PctPrivateCoverage', 'PctPublicCoverage'),
#  ('PctPrivateCoverage', 'PctPublicCoverageAlone'),
#  ('PctPrivateCoverage', 'PctWhite'),
#  ('PctPrivateCoverage', 'PctBlack'),
#  ('PctPrivateCoverage', 'PctAsian'),
#  ('PctPrivateCoverage', 'PctOtherRace'),
#  ('PctPrivateCoverage', 'PctMarriedHouseholds'),
#  ('PctPrivateCoverage', 'BirthRate'),
#  ('PctPrivateCoverage', 'State'),
#  ('PctPrivateCoverageAlone', 'PctEmpPrivCoverage'),
#  ('PctPrivateCoverageAlone', 'PctPublicCoverage'),
#  ('PctPrivateCoverageAlone', 'PctPublicCoverageAlone'),
#  ('PctPrivateCoverageAlone', 'PctWhite'),
#  ('PctPrivateCoverageAlone', 'PctBlack'),
#  ('PctPrivateCoverageAlone', 'PctAsian'),
#  ('PctPrivateCoverageAlone', 'PctOtherRace'),
#  ('PctPrivateCoverageAlone', 'PctMarriedHouseholds'),
#  ('PctPrivateCoverageAlone', 'BirthRate'),
#  ('PctPrivateCoverageAlone', 'State'),
#  ('PctEmpPrivCoverage', 'PctPublicCoverage'),
#  ('PctEmpPrivCoverage', 'PctPublicCoverageAlone'),
#  ('PctEmpPrivCoverage', 'PctWhite'),
#  ('PctEmpPrivCoverage', 'PctBlack'),
#  ('PctEmpPrivCoverage', 'PctAsian'),
#  ('PctEmpPrivCoverage', 'PctOtherRace'),
#  ('PctEmpPrivCoverage', 'PctMarriedHouseholds'),
#  ('PctEmpPrivCoverage', 'BirthRate'),
#  ('PctEmpPrivCoverage', 'State'),
#  ('PctPublicCoverage', 'PctPublicCoverageAlone'),
#  ('PctPublicCoverage', 'PctWhite'),
#  ('PctPublicCoverage', 'PctBlack'),
#  ('PctPublicCoverage', 'PctAsian'),
#  ('PctPublicCoverage', 'PctOtherRace'),
#  ('PctPublicCoverage', 'PctMarriedHouseholds'),
#  ('PctPublicCoverage', 'BirthRate'),
#  ('PctPublicCoverage', 'State'),
#  ('PctPublicCoverageAlone', 'PctWhite'),
#  ('PctPublicCoverageAlone', 'PctBlack'),
#  ('PctPublicCoverageAlone', 'PctAsian'),
#  ('PctPublicCoverageAlone', 'PctOtherRace'),
#  ('PctPublicCoverageAlone', 'PctMarriedHouseholds'),
#  ('PctPublicCoverageAlone', 'BirthRate'),
#  ('PctPublicCoverageAlone', 'State'),
#  ('PctWhite', 'PctBlack'),
#  ('PctWhite', 'PctAsian'),
#  ('PctWhite', 'PctOtherRace'),
#  ('PctWhite', 'PctMarriedHouseholds'),
#  ('PctWhite', 'BirthRate'),
#  ('PctWhite', 'State'),
#  ('PctBlack', 'PctAsian'),
#  ('PctBlack', 'PctOtherRace'),
#  ('PctBlack', 'PctMarriedHouseholds'),
#  ('PctBlack', 'BirthRate'),
#  ('PctBlack', 'State'),
#  ('PctAsian', 'PctOtherRace'),
#  ('PctAsian', 'PctMarriedHouseholds'),
#  ('PctAsian', 'BirthRate'),
#  ('PctAsian', 'State'),
#  ('PctOtherRace', 'PctMarriedHouseholds'),
#  ('PctOtherRace', 'BirthRate'),
#  ('PctOtherRace', 'State'),
#  ('PctMarriedHouseholds', 'BirthRate'),
#  ('PctMarriedHouseholds', 'State'),
#  ('BirthRate', 'State'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'incidenceRate'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'medIncome'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'popEst2015'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'povertyPercent'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'studyPerCap'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'MedianAge'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'MedianAgeMale'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'MedianAgeFemale'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PercentMarried'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctNoHS18_24'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctHS18_24'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctHS25_Over'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctPublicCoverage'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctWhite'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctBlack'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctAsian'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctOtherRace'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'BirthRate'),
#  ('avgAnnCount', 'avgDeathsPerYear', 'State'),
#  ('avgAnnCount', 'incidenceRate', 'medIncome'),
#  ('avgAnnCount', 'incidenceRate', 'popEst2015'),
#  ('avgAnnCount', 'incidenceRate', 'povertyPercent'),
#  ('avgAnnCount', 'incidenceRate', 'studyPerCap'),
#  ('avgAnnCount', 'incidenceRate', 'MedianAge'),
#  ('avgAnnCount', 'incidenceRate', 'MedianAgeMale'),
#  ('avgAnnCount', 'incidenceRate', 'MedianAgeFemale'),
#  ('avgAnnCount', 'incidenceRate', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'incidenceRate', 'PercentMarried'),
#  ('avgAnnCount', 'incidenceRate', 'PctNoHS18_24'),
#  ('avgAnnCount', 'incidenceRate', 'PctHS18_24'),
#  ('avgAnnCount', 'incidenceRate', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'incidenceRate', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'incidenceRate', 'PctHS25_Over'),
#  ('avgAnnCount', 'incidenceRate', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'incidenceRate', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'incidenceRate', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'incidenceRate', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'incidenceRate', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'incidenceRate', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'incidenceRate', 'PctPublicCoverage'),
#  ('avgAnnCount', 'incidenceRate', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'incidenceRate', 'PctWhite'),
#  ('avgAnnCount', 'incidenceRate', 'PctBlack'),
#  ('avgAnnCount', 'incidenceRate', 'PctAsian'),
#  ('avgAnnCount', 'incidenceRate', 'PctOtherRace'),
#  ('avgAnnCount', 'incidenceRate', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'incidenceRate', 'BirthRate'),
#  ('avgAnnCount', 'incidenceRate', 'State'),
#  ('avgAnnCount', 'medIncome', 'popEst2015'),
#  ('avgAnnCount', 'medIncome', 'povertyPercent'),
#  ('avgAnnCount', 'medIncome', 'studyPerCap'),
#  ('avgAnnCount', 'medIncome', 'MedianAge'),
#  ('avgAnnCount', 'medIncome', 'MedianAgeMale'),
#  ('avgAnnCount', 'medIncome', 'MedianAgeFemale'),
#  ('avgAnnCount', 'medIncome', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'medIncome', 'PercentMarried'),
#  ('avgAnnCount', 'medIncome', 'PctNoHS18_24'),
#  ('avgAnnCount', 'medIncome', 'PctHS18_24'),
#  ('avgAnnCount', 'medIncome', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'medIncome', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'medIncome', 'PctHS25_Over'),
#  ('avgAnnCount', 'medIncome', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'medIncome', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'medIncome', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'medIncome', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'medIncome', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'medIncome', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'medIncome', 'PctPublicCoverage'),
#  ('avgAnnCount', 'medIncome', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'medIncome', 'PctWhite'),
#  ('avgAnnCount', 'medIncome', 'PctBlack'),
#  ('avgAnnCount', 'medIncome', 'PctAsian'),
#  ('avgAnnCount', 'medIncome', 'PctOtherRace'),
#  ('avgAnnCount', 'medIncome', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'medIncome', 'BirthRate'),
#  ('avgAnnCount', 'medIncome', 'State'),
#  ('avgAnnCount', 'popEst2015', 'povertyPercent'),
#  ('avgAnnCount', 'popEst2015', 'studyPerCap'),
#  ('avgAnnCount', 'popEst2015', 'MedianAge'),
#  ('avgAnnCount', 'popEst2015', 'MedianAgeMale'),
#  ('avgAnnCount', 'popEst2015', 'MedianAgeFemale'),
#  ('avgAnnCount', 'popEst2015', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'popEst2015', 'PercentMarried'),
#  ('avgAnnCount', 'popEst2015', 'PctNoHS18_24'),
#  ('avgAnnCount', 'popEst2015', 'PctHS18_24'),
#  ('avgAnnCount', 'popEst2015', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'popEst2015', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'popEst2015', 'PctHS25_Over'),
#  ('avgAnnCount', 'popEst2015', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'popEst2015', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'popEst2015', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'popEst2015', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'popEst2015', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'popEst2015', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'popEst2015', 'PctPublicCoverage'),
#  ('avgAnnCount', 'popEst2015', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'popEst2015', 'PctWhite'),
#  ('avgAnnCount', 'popEst2015', 'PctBlack'),
#  ('avgAnnCount', 'popEst2015', 'PctAsian'),
#  ('avgAnnCount', 'popEst2015', 'PctOtherRace'),
#  ('avgAnnCount', 'popEst2015', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'popEst2015', 'BirthRate'),
#  ('avgAnnCount', 'popEst2015', 'State'),
#  ('avgAnnCount', 'povertyPercent', 'studyPerCap'),
#  ('avgAnnCount', 'povertyPercent', 'MedianAge'),
#  ('avgAnnCount', 'povertyPercent', 'MedianAgeMale'),
#  ('avgAnnCount', 'povertyPercent', 'MedianAgeFemale'),
#  ('avgAnnCount', 'povertyPercent', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'povertyPercent', 'PercentMarried'),
#  ('avgAnnCount', 'povertyPercent', 'PctNoHS18_24'),
#  ('avgAnnCount', 'povertyPercent', 'PctHS18_24'),
#  ('avgAnnCount', 'povertyPercent', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'povertyPercent', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'povertyPercent', 'PctHS25_Over'),
#  ('avgAnnCount', 'povertyPercent', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'povertyPercent', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'povertyPercent', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'povertyPercent', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'povertyPercent', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'povertyPercent', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'povertyPercent', 'PctPublicCoverage'),
#  ('avgAnnCount', 'povertyPercent', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'povertyPercent', 'PctWhite'),
#  ('avgAnnCount', 'povertyPercent', 'PctBlack'),
#  ('avgAnnCount', 'povertyPercent', 'PctAsian'),
#  ('avgAnnCount', 'povertyPercent', 'PctOtherRace'),
#  ('avgAnnCount', 'povertyPercent', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'povertyPercent', 'BirthRate'),
#  ('avgAnnCount', 'povertyPercent', 'State'),
#  ('avgAnnCount', 'studyPerCap', 'MedianAge'),
#  ('avgAnnCount', 'studyPerCap', 'MedianAgeMale'),
#  ('avgAnnCount', 'studyPerCap', 'MedianAgeFemale'),
#  ('avgAnnCount', 'studyPerCap', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'studyPerCap', 'PercentMarried'),
#  ('avgAnnCount', 'studyPerCap', 'PctNoHS18_24'),
#  ('avgAnnCount', 'studyPerCap', 'PctHS18_24'),
#  ('avgAnnCount', 'studyPerCap', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'studyPerCap', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'studyPerCap', 'PctHS25_Over'),
#  ('avgAnnCount', 'studyPerCap', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'studyPerCap', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'studyPerCap', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'studyPerCap', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'studyPerCap', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'studyPerCap', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'studyPerCap', 'PctPublicCoverage'),
#  ('avgAnnCount', 'studyPerCap', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'studyPerCap', 'PctWhite'),
#  ('avgAnnCount', 'studyPerCap', 'PctBlack'),
#  ('avgAnnCount', 'studyPerCap', 'PctAsian'),
#  ('avgAnnCount', 'studyPerCap', 'PctOtherRace'),
#  ('avgAnnCount', 'studyPerCap', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'studyPerCap', 'BirthRate'),
#  ('avgAnnCount', 'studyPerCap', 'State'),
#  ('avgAnnCount', 'MedianAge', 'MedianAgeMale'),
#  ('avgAnnCount', 'MedianAge', 'MedianAgeFemale'),
#  ('avgAnnCount', 'MedianAge', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'MedianAge', 'PercentMarried'),
#  ('avgAnnCount', 'MedianAge', 'PctNoHS18_24'),
#  ('avgAnnCount', 'MedianAge', 'PctHS18_24'),
#  ('avgAnnCount', 'MedianAge', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'MedianAge', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'MedianAge', 'PctHS25_Over'),
#  ('avgAnnCount', 'MedianAge', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'MedianAge', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'MedianAge', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'MedianAge', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'MedianAge', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'MedianAge', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'MedianAge', 'PctPublicCoverage'),
#  ('avgAnnCount', 'MedianAge', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'MedianAge', 'PctWhite'),
#  ('avgAnnCount', 'MedianAge', 'PctBlack'),
#  ('avgAnnCount', 'MedianAge', 'PctAsian'),
#  ('avgAnnCount', 'MedianAge', 'PctOtherRace'),
#  ('avgAnnCount', 'MedianAge', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'MedianAge', 'BirthRate'),
#  ('avgAnnCount', 'MedianAge', 'State'),
#  ('avgAnnCount', 'MedianAgeMale', 'MedianAgeFemale'),
#  ('avgAnnCount', 'MedianAgeMale', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'MedianAgeMale', 'PercentMarried'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctNoHS18_24'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctHS18_24'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctHS25_Over'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctPublicCoverage'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctWhite'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctBlack'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctAsian'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctOtherRace'),
#  ('avgAnnCount', 'MedianAgeMale', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'MedianAgeMale', 'BirthRate'),
#  ('avgAnnCount', 'MedianAgeMale', 'State'),
#  ('avgAnnCount', 'MedianAgeFemale', 'AvgHouseholdSize'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PercentMarried'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctNoHS18_24'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctHS18_24'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctHS25_Over'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctPublicCoverage'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctWhite'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctBlack'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctAsian'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctOtherRace'),
#  ('avgAnnCount', 'MedianAgeFemale', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'MedianAgeFemale', 'BirthRate'),
#  ('avgAnnCount', 'MedianAgeFemale', 'State'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PercentMarried'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctNoHS18_24'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctHS18_24'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctHS25_Over'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctPublicCoverage'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctWhite'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctBlack'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctAsian'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctOtherRace'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'BirthRate'),
#  ('avgAnnCount', 'AvgHouseholdSize', 'State'),
#  ('avgAnnCount', 'PercentMarried', 'PctNoHS18_24'),
#  ('avgAnnCount', 'PercentMarried', 'PctHS18_24'),
#  ('avgAnnCount', 'PercentMarried', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'PercentMarried', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'PercentMarried', 'PctHS25_Over'),
#  ('avgAnnCount', 'PercentMarried', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PercentMarried', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PercentMarried', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PercentMarried', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PercentMarried', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PercentMarried', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PercentMarried', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PercentMarried', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PercentMarried', 'PctWhite'),
#  ('avgAnnCount', 'PercentMarried', 'PctBlack'),
#  ('avgAnnCount', 'PercentMarried', 'PctAsian'),
#  ('avgAnnCount', 'PercentMarried', 'PctOtherRace'),
#  ('avgAnnCount', 'PercentMarried', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PercentMarried', 'BirthRate'),
#  ('avgAnnCount', 'PercentMarried', 'State'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctHS18_24'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctHS25_Over'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctWhite'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctBlack'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctAsian'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctOtherRace'),
#  ('avgAnnCount', 'PctNoHS18_24', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctNoHS18_24', 'BirthRate'),
#  ('avgAnnCount', 'PctNoHS18_24', 'State'),
#  ('avgAnnCount', 'PctHS18_24', 'PctSomeCol18_24'),
#  ('avgAnnCount', 'PctHS18_24', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'PctHS18_24', 'PctHS25_Over'),
#  ('avgAnnCount', 'PctHS18_24', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctHS18_24', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctHS18_24', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctHS18_24', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctHS18_24', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctHS18_24', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctHS18_24', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctHS18_24', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctHS18_24', 'PctWhite'),
#  ('avgAnnCount', 'PctHS18_24', 'PctBlack'),
#  ('avgAnnCount', 'PctHS18_24', 'PctAsian'),
#  ('avgAnnCount', 'PctHS18_24', 'PctOtherRace'),
#  ('avgAnnCount', 'PctHS18_24', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctHS18_24', 'BirthRate'),
#  ('avgAnnCount', 'PctHS18_24', 'State'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctBachDeg18_24'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctHS25_Over'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctWhite'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctBlack'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctAsian'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctOtherRace'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'BirthRate'),
#  ('avgAnnCount', 'PctSomeCol18_24', 'State'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctHS25_Over'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctWhite'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctBlack'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctAsian'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctOtherRace'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'BirthRate'),
#  ('avgAnnCount', 'PctBachDeg18_24', 'State'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctBachDeg25_Over'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctWhite'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctBlack'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctAsian'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctOtherRace'),
#  ('avgAnnCount', 'PctHS25_Over', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctHS25_Over', 'BirthRate'),
#  ('avgAnnCount', 'PctHS25_Over', 'State'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctEmployed16_Over'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctWhite'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctBlack'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctAsian'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctOtherRace'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'BirthRate'),
#  ('avgAnnCount', 'PctBachDeg25_Over', 'State'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctUnemployed16_Over'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctWhite'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctBlack'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctAsian'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctOtherRace'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'BirthRate'),
#  ('avgAnnCount', 'PctEmployed16_Over', 'State'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctPrivateCoverage'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctWhite'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctBlack'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctAsian'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctOtherRace'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'BirthRate'),
#  ('avgAnnCount', 'PctUnemployed16_Over', 'State'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctPrivateCoverageAlone'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctWhite'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctBlack'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctAsian'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctOtherRace'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'BirthRate'),
#  ('avgAnnCount', 'PctPrivateCoverage', 'State'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctEmpPrivCoverage'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctWhite'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctBlack'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctAsian'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctOtherRace'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'BirthRate'),
#  ('avgAnnCount', 'PctPrivateCoverageAlone', 'State'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctPublicCoverage'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctWhite'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctBlack'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctAsian'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctOtherRace'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'BirthRate'),
#  ('avgAnnCount', 'PctEmpPrivCoverage', 'State'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctPublicCoverageAlone'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctWhite'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctBlack'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctAsian'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctOtherRace'),
#  ('avgAnnCount', 'PctPublicCoverage', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctPublicCoverage', 'BirthRate'),
#  ('avgAnnCount', 'PctPublicCoverage', 'State'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'PctWhite'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'PctBlack'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'PctAsian'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'PctOtherRace'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'BirthRate'),
#  ('avgAnnCount', 'PctPublicCoverageAlone', 'State'),
#  ('avgAnnCount', 'PctWhite', 'PctBlack'),
#  ('avgAnnCount', 'PctWhite', 'PctAsian'),
#  ('avgAnnCount', 'PctWhite', 'PctOtherRace'),
#  ('avgAnnCount', 'PctWhite', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctWhite', 'BirthRate'),
#  ('avgAnnCount', 'PctWhite', 'State'),
#  ('avgAnnCount', 'PctBlack', 'PctAsian'),
#  ('avgAnnCount', 'PctBlack', 'PctOtherRace'),
#  ('avgAnnCount', 'PctBlack', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctBlack', 'BirthRate'),
#  ('avgAnnCount', 'PctBlack', 'State'),
#  ('avgAnnCount', 'PctAsian', 'PctOtherRace'),
#  ('avgAnnCount', 'PctAsian', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctAsian', 'BirthRate'),
#  ('avgAnnCount', 'PctAsian', 'State'),
#  ('avgAnnCount', 'PctOtherRace', 'PctMarriedHouseholds'),
#  ('avgAnnCount', 'PctOtherRace', 'BirthRate'),
#  ('avgAnnCount', 'PctOtherRace', 'State'),
#  ('avgAnnCount', 'PctMarriedHouseholds', 'BirthRate'),
#  ('avgAnnCount', 'PctMarriedHouseholds', 'State'),
#  ('avgAnnCount', 'BirthRate', 'State'),
#  ('avgDeathsPerYear', 'incidenceRate', 'medIncome'),
#  ('avgDeathsPerYear', 'incidenceRate', 'popEst2015'),
#  ('avgDeathsPerYear', 'incidenceRate', 'povertyPercent'),
#  ('avgDeathsPerYear', 'incidenceRate', 'studyPerCap'),
#  ('avgDeathsPerYear', 'incidenceRate', 'MedianAge'),
#  ('avgDeathsPerYear', 'incidenceRate', 'MedianAgeMale'),
#  ...]

# %%
# To split the dataset into train and test datasets
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def train_model(features, target):
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.2, random_state = 10)
    model = KNeighborsClassifier(n_neighbors=9)
    model.fit(features_train, target_train)
    score = model.score(features_test, target_test)
    return score
