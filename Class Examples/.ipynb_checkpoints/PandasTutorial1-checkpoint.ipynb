# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.shape
# Out:
# (403, 16)

# %%
df.head() # Show first 5 rows
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.tail() # last 5 rows
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb location  age  gender  \
# 398  41506  296.0       369  46.0    6.4  16.110001   Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000   Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000   Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000   Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN   Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  waist   hip
# 398    69.0   173.0  medium  138.0   94.0   35.0  39.0
# 399    63.0   154.0  medium  140.0  100.0   32.0  43.0
# 400    69.0   167.0   small  120.0   70.0   33.0  40.0
# 401    63.0   197.0  medium  120.0   78.0   41.0  48.0
# 402    64.0   220.0  medium  100.0   72.0   49.0  58.0

# %%
df.sample(5) # X randomly selected rows
# Out:
#         id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  \
# 159  15008  181.0        83  44.0    4.1   4.03      Louisa   39  female
# 76    4500  242.0       108  53.0    4.6   5.47  Buckingham   46  female
# 149  12778  164.0        71  63.0    2.6   4.51  Buckingham   20    male
# 11    1029  215.0       128  34.0    6.3   4.97      Louisa   38  female
# 214  15802  155.0        58  69.0    2.2   4.17  Buckingham   26    male
#
#      height  weight   frame  bp.1s  bp.1d  waist   hip
# 159    66.0   255.0  medium  140.0   98.0   46.0  54.0
# 76     62.0   183.0  medium  130.0   86.0   37.0  45.0
# 149    72.0   145.0   small  108.0   78.0   29.0  36.0
# 11     58.0   195.0  medium  102.0   68.0   42.0  50.0
# 214    73.0   174.0   small  110.0   76.0   30.0  35.0

# %%
df.describe() # Show statistical summary / num fields only
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  402.000000  403.000000  402.000000  402.000000
# mean   15978.310174  207.845771  106.672457   50.445274    4.521642
# std    11881.122124   44.445557   53.076655   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb         age      height      weight       bp.1s       bp.1d  \
# count  390.000000  403.000000  398.000000  402.000000  398.000000  398.000000
# mean     5.589769   46.851117   66.020101  177.592040  136.904523   83.321608
# std      2.242595   16.312333    3.918515   40.340666   22.741033   13.589227
# ...

# %%
# Select single column
df['chol']
# Out:
# 0      203.0
# 1      165.0
# 2      228.0
# 3       78.0
# 4      249.0
#        ...
# 398    296.0
# 399    284.0
# 400    194.0
# 401    199.0
# 402    159.0
# Name: chol, Length: 403, dtype: float64

# %%
# Select multiple columns
df[['id','chol','age']]
# Out:
#         id   chol  age
# 0     1000  203.0   46
# 1     1001  165.0   29
# 2     1002  228.0   58
# 3     1003   78.0   67
# 4     1005  249.0   64
# ..     ...    ...  ...
# 398  41506  296.0   53
# 399  41507  284.0   51
# 400  41510  194.0   29
# 401  41752  199.0   41
# 402  41756  159.0   68
#
# [403 rows x 3 columns]

# %%
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.loc[0:5]
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0
# 5   190.0   large  132.0   86.0   36.0  42.0

# %%
df.loc[0:5]
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0
# 5   190.0   large  132.0   86.0   36.0  42.0

# %%
df.iloc[0:5,[0,1,3,7]]
# Out:
#      id   chol   hdl  age
# 0  1000  203.0  56.0   46
# 1  1001  165.0  24.0   29
# 2  1002  228.0  37.0   58
# 3  1003   78.0  12.0   67
# 4  1005  249.0  28.0   64

# %%
df[['id','chol','age']].loc[0:5]
# Out:
#      id   chol  age
# 0  1000  203.0   46
# 1  1001  165.0   29
# 2  1002  228.0   58
# 3  1003   78.0   67
# 4  1005  249.0   64
# 5  1008  248.0   34

# %%
# Sort data frame
temp = df[['id','chol','age']].loc[0:5]
temp.sort_values('chol', ascending=False, inplace=True)

# %%
temp
# Out:
#      id   chol  age
# 4  1005  249.0   64
# 5  1008  248.0   34
# 2  1002  228.0   58
# 0  1000  203.0   46
# 1  1001  165.0   29
# 3  1003   78.0   67

# %%
# Concat by rows
df1 = df[['id','chol','age']].loc[0:3]
df1
# Out:
#      id   chol  age
# 0  1000  203.0   46
# 1  1001  165.0   29
# 2  1002  228.0   58
# 3  1003   78.0   67

# %%
df2 = df[['id','chol','age']].loc[4:6]
df2
# Out:
#      id   chol  age
# 4  1005  249.0   64
# 5  1008  248.0   34
# 6  1011  195.0   30

# %%
dfs_to_concat = [df1, df2]
df3 = pd.concat(dfs_to_concat)
df3
# Out:
#      id   chol  age
# 0  1000  203.0   46
# 1  1001  165.0   29
# 2  1002  228.0   58
# 3  1003   78.0   67
# 4  1005  249.0   64
# 5  1008  248.0   34
# 6  1011  195.0   30
