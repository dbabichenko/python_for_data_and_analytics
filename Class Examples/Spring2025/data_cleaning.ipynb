# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %matplotlib inline

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.dtypes
# Out:
# id            int64
# chol        float64
# stab.glu      int64
# hdl         float64
# ratio       float64
# glyhb       float64
# location     object
# age           int64
# gender       object
# height      float64
# weight      float64
# frame        object
# bp.1s       float64
# bp.1d       float64
# waist       float64
# hip         float64
# dtype: object

# %%
df.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  402.000000  403.000000  402.000000  402.000000
# mean   15978.310174  207.845771  106.672457   50.445274    4.521642
# std    11881.122124   44.445557   53.076655   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb         age      height      weight       bp.1s       bp.1d  \
# count  390.000000  403.000000  398.000000  402.000000  398.000000  398.000000
# mean     5.589769   46.851117   66.020101  177.592040  136.904523   83.321608
# std      2.242595   16.312333    3.918515   40.340666   22.741033   13.589227
# ...

# %%
sn.histplot(data=df, x='age', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sn.histplot(data=df, x='chol', kde=True)
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %% [markdown]
# 1. high = 1%
# 2. medium = 49%
# 3. low = 50%
#
# 80% = training
#
# 20% = validation

# %%
df['chol'].mean()
# Out:
# 207.84577114427861

# %%
df['chol'].median()
# Out:
# 204.0

# %%
for col in df.select_dtypes(include='number').columns:
    sn.histplot(data=df, x=col, kde=True)
    plt.show()

# %%
sn.histplot(data=df, x='weight', kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sn.boxplot(data=df, x='weight')
# Out:
# <Axes: xlabel='weight'>

# %%
df.query('weight >= 270')
# Out:
#         id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  \
# 22    1254  203.0       299  43.0    4.7  12.74  Buckingham   38  female
# 55    2763  193.0       106  63.0    3.1   6.35  Buckingham   20  female
# 134  12501  192.0       109  44.0    4.4   4.86  Buckingham   43  female
# 147  12769  347.0       197  42.0    8.3   6.34  Buckingham   36    male
# 150  13250  181.0       255  26.0    7.0   9.58  Buckingham   50    male
# 160  15010  151.0        85  48.0    3.1   4.38      Louisa   33    male
# 171  15276  215.0       110  36.0    6.0   9.82      Louisa   51  female
# 256  17805  235.0       109  59.0    4.0   7.48  Buckingham   62  female
# 268  17835  230.0        86  37.0    6.2   4.39  Buckingham   23    male
# 276  20267  191.0        74  33.0    5.8   5.35      Louisa   40    male
# 278  20272  184.0        92  36.0    5.1   4.81      Louisa   40  female
# 352  40500  226.0       100  65.0    3.5   4.83      Louisa   27    male
#
# ...

# %%
sn.histplot(data=df, x='weight', kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %% [markdown]
# ### Two ways to normalize distribution:
# 1. Take square root of each value
# 2. Take natural log of each value

# %%
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df['weight_transformed'] = 0
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip  weight_transformed
# 0   121.0  medium  118.0   59.0   29.0  38.0                   0
# 1   218.0   large  112.0   68.0   46.0  48.0                   0
# 2   256.0   large  190.0   92.0   49.0  57.0                   0
# 3   119.0   large  110.0   50.0   33.0  38.0                   0
# 4   183.0  medium  138.0   80.0   44.0  41.0                   0

# %%
def add_num(x):
    return x + 10;

# %%
l = [1, 2, 3, 4, 5]

# %%
for i in range(0, len(l)):
    l[i] = add_num(l[i])

print(l)
# Out:
# [11, 12, 13, 14, 15]

# %%
df['weight_copy'] = df['weight']
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip  weight_transformed  weight_copy
# 0   121.0  medium  118.0   59.0   29.0  38.0                   0        121.0
# 1   218.0   large  112.0   68.0   46.0  48.0                   0        218.0
# 2   256.0   large  190.0   92.0   49.0  57.0                   0        256.0
# 3   119.0   large  110.0   50.0   33.0  38.0                   0        119.0
# 4   183.0  medium  138.0   80.0   44.0  41.0                   0        183.0

# %%
df['weight_copy'] = df['weight_copy'].apply(lambda x: add_num(x))
df[['weight', 'weight_copy']].head()
# Out:
#    weight  weight_copy
# 0   121.0        131.0
# 1   218.0        228.0
# 2   256.0        266.0
# 3   119.0        129.0
# 4   183.0        193.0

# %%
import math

df['weight_transformed'] = df['weight'].apply(lambda x: math.sqrt(x))
df[['weight', 'weight_transformed']].head()
# Out:
#    weight  weight_transformed
# 0   121.0           11.000000
# 1   218.0           14.764823
# 2   256.0           16.000000
# 3   119.0           10.908712
# 4   183.0           13.527749

# %%
sn.histplot(data=df, x='weight', kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sn.histplot(data=df, x='weight_transformed', kde=True)
# Out:
# <Axes: xlabel='weight_transformed', ylabel='Count'>

# %%
df['stab_glu_t'] = df['stab.glu'].apply(lambda x: math.sqrt(x))
df[['stab.glu', 'stab_glu_t']].head()
# Out:
#    stab.glu  stab_glu_t
# 0        82    9.055385
# 1        97    9.848858
# 2        92    9.591663
# 3        93    9.643651
# 4        90    9.486833

# %%
sn.histplot(data=df, x='stab.glu', kde=True)
# Out:
# <Axes: xlabel='stab.glu', ylabel='Count'>

# %%
sn.histplot(data=df, x='stab_glu_t', kde=True)
# Out:
# <Axes: xlabel='stab_glu_t', ylabel='Count'>

# %%
df['stab_glu_t'] = df['stab.glu'].apply(lambda x: math.log(x))
df[['stab.glu', 'stab_glu_t']].head()
# Out:
#    stab.glu  stab_glu_t
# 0        82    4.406719
# 1        97    4.574711
# 2        92    4.521789
# 3        93    4.532599
# 4        90    4.499810

# %%
sn.histplot(data=df, x='stab_glu_t', kde=True)
# Out:
# <Axes: xlabel='stab_glu_t', ylabel='Count'>

# %%
df_broken = pd.read_csv('diabetes_bad_data.csv')
df_broken.head()
# Out:
#      id chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df_broken.dtypes
# Out:
# id            int64
# chol         object
# stab.glu      int64
# hdl         float64
# ratio       float64
# glyhb       float64
# location     object
# age           int64
# gender       object
# height      float64
# weight      float64
# frame        object
# bp.1s       float64
# bp.1d       float64
# waist       float64
# hip         float64
# dtype: object

# %%
for idx, row in df_broken.iterrows():
    if not str(row['chol']).isdigit():
        print(idx, row['chol'])
# Out:
# 27 nan
# 51 1_237

# %%
df_broken.loc[51]
# Out:
# id                2756
# chol             1_237
# stab.glu            87
# hdl               41.0
# ratio              5.8
# glyhb             5.35
# location    Buckingham
# age                 43
# gender          female
# height            64.0
# weight           181.0
# frame           medium
# bp.1s            104.0
# bp.1d             90.0
# waist             36.0
# hip               46.0
# Name: 51, dtype: object

# %%
df_broken.at[51, 'chol'] = df_broken.at[51, 'chol'].replace('_', '')
df_broken.at[51, 'chol']
# Out:
# '1237'

# %%
df_broken.dtypes
# Out:
# id            int64
# chol         object
# stab.glu      int64
# hdl         float64
# ratio       float64
# glyhb       float64
# location     object
# age           int64
# gender       object
# height      float64
# weight      float64
# frame        object
# bp.1s       float64
# bp.1d       float64
# waist       float64
# hip         float64
# dtype: object

# %%
df_broken['chol'] = df_broken['chol'].astype('float')
df_broken.dtypes
# Out:
# id            int64
# chol        float64
# stab.glu      int64
# hdl         float64
# ratio       float64
# glyhb       float64
# location     object
# age           int64
# gender       object
# height      float64
# weight      float64
# frame        object
# bp.1s       float64
# bp.1d       float64
# waist       float64
# hip         float64
# dtype: object

# %%
titanic = pd.read_csv('titanic_train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sn.heatmap(data=titanic.isnull())
# Out:
# <Axes: >

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.shape[0]
# Out:
# 891

# %%
temp = pd.DataFrame(titanic.isnull().sum())
temp.reset_index(inplace=True)
temp.columns = ['col_name', 'missing_count']
temp['missing_count'] = temp['missing_count'] / titanic.shape[0] * 100
temp.query('missing_count > 0')
# Out:
#     col_name  missing_count
# 5        Age      19.865320
# 10     Cabin      77.104377
# 11  Embarked       0.224467

# %%
titanic.drop('Cabin', axis=1, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.shape
# Out:
# (403, 19)

# %%
df.isnull().sum()
# Out:
# id                     0
# chol                   1
# stab.glu               0
# hdl                    1
# ratio                  1
# glyhb                 13
# location               0
# age                    0
# gender                 0
# height                 5
# weight                 1
# frame                 12
# bp.1s                  5
# bp.1d                  5
# waist                  2
# hip                    2
# weight_transformed     1
# weight_copy            1
# stab_glu_t             0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                    0
# chol                  0
# stab.glu              0
# hdl                   0
# ratio                 0
# glyhb                 0
# location              0
# age                   0
# gender                0
# height                0
# weight                0
# frame                 0
# bp.1s                 0
# bp.1d                 0
# waist                 0
# hip                   0
# weight_transformed    0
# weight_copy           0
# stab_glu_t            0
# dtype: int64

# %%
df = pd.read_csv('diabetes.csv')
df.isnull().sum()
# Out:
# id           0
# chol         1
# stab.glu     0
# hdl          1
# ratio        1
# glyhb       13
# location     0
# age          0
# gender       0
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# dtype: int64

# %%
sn.histplot(data = df, x = 'glyhb', kde=True)
# Out:
# <Axes: xlabel='glyhb', ylabel='Count'>

# %%
df['glyhb'].mean()
# Out:
# 5.58976923628718

# %%
df['glyhb'].fillna(df['glyhb'].mean(), inplace=True)
# Out:
# /var/folders/6d/xqywj2xx2llc_k2t6nkshrgh0000gn/T/ipykernel_39032/3008901941.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['glyhb'].fillna(df['glyhb'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# id           0
# chol         1
# stab.glu     0
# hdl          1
# ratio        1
# glyhb        0
# location     0
# age          0
# gender       0
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# dtype: int64

# %%
eng = pd.read_csv('Software Engineer Salaries.csv')
eng.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary
# 0   $68K - $94K (Glassdoor est.)
# 1   $61K - $104K (Employer est.)
# 2  $95K - $118K (Glassdoor est.)
# 3   $97K - $145K (Employer est.)
# 4  $85K - $108K (Glassdoor est.)

# %%
import re

def extract_number(string):
  """Extracts the numeric part of a string."""
  return re.findall(r'\d+', string)
    
def split_salary(salary):
    min_salary = 0
    max_salary = 0
    data_source = ''
    temp = salary.split('(')
    if len(temp) == 2:
        data_source = temp[1]
        temp = temp[0].split('-')
        if len(temp) == 2:
            min_salary = int(extract_number(temp[0])[0])
            max_salary = int(extract_number(temp[1])[0])
    return min_salary, max_salary, data_source

# %%
split_salary('$68K - $94K¬†(Glassdoor est.)')
# Out:
# (68, 94, 'Glassdoor est.)')

# %% [markdown]
# Things to ask Google: how to apply a lambda function to a multiple columns in pandas

# %%
import sklearn.preprocessing as prep
#from sklearn.preprocessing import StandardScaler

# %%
df['chol'].describe()
# Out:
# count    402.000000
# mean     207.845771
# std       44.445557
# min       78.000000
# 25%      179.000000
# 50%      204.000000
# 75%      230.000000
# max      443.000000
# Name: chol, dtype: float64

# %%
sn.histplot(data=df, x='chol', kde=True)
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %%
df['chol_normalized'] = prep.scale(df['chol'])
df[['chol_normalized', 'chol']].head()
# Out:
#    chol_normalized   chol
# 0        -0.109163  203.0
# 1        -0.965207  165.0
# 2         0.454024  228.0
# 3        -2.925097   78.0
# 4         0.927101  249.0

# %%
sn.histplot(data=df, x='chol_normalized', kde=True)
# Out:
# <Axes: xlabel='chol_normalized', ylabel='Count'>
