# %% [markdown]
# * https://github.com/mubaris/friendly-fortnight
# * https://mubaris.com/2017/10/01/kmeans-clustering-in-python/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)

# %%
# Creating a sample dataset with 3 clusters
X, y = make_blobs(n_samples=10000, n_features=3, centers=3)
X
# Out:
# array([[-10.93549568,   1.18069367,  -1.61661349],
#        [  8.92231095,   1.7086062 ,   0.4084967 ],
#        [ -2.76166708,  -6.74593423,   7.13000409],
#        ...,
#        [  7.30123988,   1.27560485,   0.89138036],
#        [ -2.77931974,  -7.80385821,   6.50284934],
#        [  9.17111771,   1.35526366,   2.41419727]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=3)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
print(C)
# Out:
# [[-3.34843676 -6.88166478  6.56672015]
#  [-9.97742658  1.88533203 -1.64910588]
#  [ 8.95835407  0.1724622   1.00184068]]

# %%
print(labels[:10])
# Out:
# [1 2 0 2 0 1 2 1 1 0]

# %%
import pandas as pd
df = pd.DataFrame(X)
df = pd.concat([df.reset_index(), pd.Series(labels)], axis = 1)
df.head()
# Out:
#    index          0         1         2  0
# 0      0 -10.935496  1.180694 -1.616613  1
# 1      1   8.922311  1.708606  0.408497  2
# 2      2  -2.761667 -6.745934  7.130004  0
# 3      3  10.051004  0.179888 -0.355086  2
# 4      4  -4.057543 -6.761612  6.466171  0

# %%
fig = plt.figure()
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#000000', s=100)
