# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

import matplotlib.cm as cm
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df_shots_raw = pd.read_csv('../data/shots_2007-2023.csv')
df_shots_raw.head()
# Out:
#    shotID homeTeamCode awayTeamCode  season  isPlayoffGame  game_id  \
# 0       0          TBL          NSH    2023              0    20001
# 1       1          TBL          NSH    2023              0    20001
# 2       2          TBL          NSH    2023              0    20001
# 3       3          TBL          NSH    2023              0    20001
# 4       4          TBL          NSH    2023              0    20001
#
#    homeTeamWon  id  time  timeUntilNextEvent  ...    xFroze  xRebound  \
# 0            1  10    61                 9.0  ...  0.249174  0.035816
# 1            1  11    70                26.0  ...  0.107945  0.051284
# 2            1  13   107                 2.0  ...  0.236193  0.030269
# 3            1  19   177                35.0  ...  0.198635  0.033686
# 4            1  21   231                29.0  ...  0.188582  0.027146
#
#   xPlayContinuedInZone xPlayContinuedOutsideZone xPlayStopped  xShotWasOnGoal  \
# 0             0.379310                  0.277143     0.022744        0.751320
# 1             0.464358                  0.298119     0.020588        0.589712
# 2             0.390417                  0.301375     0.025620        0.785765
# 3             0.438052                  0.291724     0.021107        0.724471
# 4             0.406288                  0.349752     0.019523        0.727481
#
#    isHomeTeam  shotWasOnGoal  teamCode  arenaAdjustedXCordABS
# 0         1.0            1.0       TBL                   59.0
# 1         1.0            1.0       TBL                   81.0
# 2         1.0            1.0       TBL                   55.0
# 3         1.0            1.0       TBL                   58.0
# 4         0.0            0.0       NSH                   64.0
#
# [5 rows x 124 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_shots_raw.dtypes)
# Out:
# shotID                                                     int64
# homeTeamCode                                              object
# awayTeamCode                                              object
# season                                                     int64
# isPlayoffGame                                              int64
# game_id                                                    int64
# homeTeamWon                                                int64
# id                                                         int64
# time                                                       int64
# timeUntilNextEvent                                       float64
# timeSinceLastEvent                                         int64
# period                                                     int64
# team                                                      object
# location                                                  object
# event                                                     object
# goal                                                       int64
# shotPlayContinuedOutsideZone                             float64
# shotPlayContinuedInZone                                    int64
# shotGoalieFroze                                            int64
# shotPlayStopped                                            int64
# shotGeneratedRebound                                       int64
# homeTeamGoals                                              int64
# awayTeamGoals                                              int64
# xCord                                                      int64
# yCord                                                      int64
# xCordAdjusted                                              int64
# yCordAdjusted                                              int64
# shotAngle                                                float64
# shotAngleAdjusted                                        float64
# shotAnglePlusRebound                                     float64
# shotAngleReboundRoyalRoad                                  int64
# shotDistance                                             float64
# shotType                                                  object
# shotOnEmptyNet                                             int64
# shotRebound                                                int64
# shotAnglePlusReboundSpeed                                float64
# shotRush                                                   int64
# speedFromLastEvent                                       float64
# lastEventxCord                                             int64
# lastEventyCord                                             int64
# distanceFromLastEvent                                    float64
# lastEventShotAngle                                       float64
# lastEventShotDistance                                    float64
# lastEventCategory                                         object
# lastEventTeam                                             object
# homeEmptyNet                                               int64
# awayEmptyNet                                               int64
# homeSkatersOnIce                                           int64
# awaySkatersOnIce                                           int64
# awayPenalty1TimeLeft                                       int64
# awayPenalty1Length                                         int64
# homePenalty1TimeLeft                                       int64
# homePenalty1Length                                         int64
# playerPositionThatDidEvent                                object
# playerNumThatDidEvent                                      int64
# playerNumThatDidLastEvent                                  int64
# lastEventxCord_adjusted                                    int64
# lastEventyCord_adjusted                                    int64
# timeSinceFaceoff                                           int64
# goalieIdForShot                                          float64
# goalieNameForShot                                         object
# shooterPlayerId                                          float64
# shooterName                                               object
# shooterLeftRight                                          object
# shooterTimeOnIce                                           int64
# shooterTimeOnIceSinceFaceoff                               int64
# shootingTeamForwardsOnIce                                  int64
# shootingTeamDefencemenOnIce                                int64
# shootingTeamAverageTimeOnIce                             float64
# shootingTeamAverageTimeOnIceOfForwards                   float64
# shootingTeamAverageTimeOnIceOfDefencemen                 float64
# shootingTeamMaxTimeOnIce                                   int64
# shootingTeamMaxTimeOnIceOfForwards                         int64
# shootingTeamMaxTimeOnIceOfDefencemen                       int64
# shootingTeamMinTimeOnIce                                   int64
# shootingTeamMinTimeOnIceOfForwards                         int64
# shootingTeamMinTimeOnIceOfDefencemen                       int64
# shootingTeamAverageTimeOnIceSinceFaceoff                 float64
# shootingTeamAverageTimeOnIceOfForwardsSinceFaceoff       float64
# shootingTeamAverageTimeOnIceOfDefencemenSinceFaceoff     float64
# shootingTeamMaxTimeOnIceSinceFaceoff                       int64
# shootingTeamMaxTimeOnIceOfForwardsSinceFaceoff             int64
# shootingTeamMaxTimeOnIceOfDefencemenSinceFaceoff           int64
# shootingTeamMinTimeOnIceSinceFaceoff                       int64
# shootingTeamMinTimeOnIceOfForwardsSinceFaceoff             int64
# shootingTeamMinTimeOnIceOfDefencemenSinceFaceoff           int64
# defendingTeamForwardsOnIce                                 int64
# defendingTeamDefencemenOnIce                               int64
# defendingTeamAverageTimeOnIce                            float64
# defendingTeamAverageTimeOnIceOfForwards                  float64
# defendingTeamAverageTimeOnIceOfDefencemen                float64
# defendingTeamMaxTimeOnIce                                  int64
# defendingTeamMaxTimeOnIceOfForwards                        int64
# defendingTeamMaxTimeOnIceOfDefencemen                      int64
# defendingTeamMinTimeOnIce                                  int64
# defendingTeamMinTimeOnIceOfForwards                        int64
# defendingTeamMinTimeOnIceOfDefencemen                      int64
# defendingTeamAverageTimeOnIceSinceFaceoff                float64
# defendingTeamAverageTimeOnIceOfForwardsSinceFaceoff      float64
# defendingTeamAverageTimeOnIceOfDefencemenSinceFaceoff    float64
# defendingTeamMaxTimeOnIceSinceFaceoff                      int64
# defendingTeamMaxTimeOnIceOfForwardsSinceFaceoff            int64
# defendingTeamMaxTimeOnIceOfDefencemenSinceFaceoff          int64
# defendingTeamMinTimeOnIceSinceFaceoff                      int64
# defendingTeamMinTimeOnIceOfForwardsSinceFaceoff            int64
# defendingTeamMinTimeOnIceOfDefencemenSinceFaceoff          int64
# offWing                                                    int64
# arenaAdjustedShotDistance                                float64
# arenaAdjustedXCord                                       float64
# arenaAdjustedYCord                                       float64
# arenaAdjustedYCordAbs                                    float64
# timeDifferenceSinceChange                                  int64
# averageRestDifference                                    float64
# xGoal                                                    float64
# xFroze                                                   float64
# xRebound                                                 float64
# xPlayContinuedInZone                                     float64
# xPlayContinuedOutsideZone                                float64
# xPlayStopped                                             float64
# xShotWasOnGoal                                           float64
# isHomeTeam                                               float64
# shotWasOnGoal                                            float64
# teamCode                                                  object
# arenaAdjustedXCordABS                                    float64
# dtype: object
