# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("diabetes.csv")

df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0      82.0  56.0    3.6   4.31  Buckingham  _46  female    62.0
# 1  1001  165.0      97.0  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0      92.0  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0      93.0  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0      90.0  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  400.000000  401.000000  402.000000  402.000000
# mean   15978.310174  207.895000  106.690773   50.445274    4.521642
# std    11881.122124   44.535069   53.206852   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.250000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb      height      weight       bp.1s       bp.1d       waist  \
# count  390.000000  398.000000  402.000000  398.000000  398.000000  401.000000
# mean     5.589769   66.020101  177.592040  136.904523   83.321608   37.900249
# std      2.242595    3.918515   40.340666   22.741033   13.589227    5.729313
# min      2.680000   52.000000   99.000000   90.000000   48.000000   26.000000
# 25%      4.380000   63.000000  151.000000  121.250000   75.000000   33.000000
# 50%      4.840000   66.000000  172.500000  136.000000   82.000000   37.000000
# 75%      5.600000   69.000000  200.000000  146.750000   90.000000   41.000000
# max     16.110001   76.000000  325.000000  250.000000  124.000000   56.000000
#
#               hip
# count  401.000000
# mean    43.039900
# std      5.656713
# min     30.000000
# 25%     39.000000
# 50%     42.000000
# 75%     46.000000
# max     64.000000

# %%
df.isnull().head()
# Out:
#       id   chol  stab.glu    hdl  ratio  glyhb  location    age  gender  \
# 0  False  False     False  False  False  False     False  False   False
# 1  False  False     False  False  False  False     False  False   False
# 2  False  False     False  False  False  False     False  False   False
# 3  False  False     False  False  False  False     False  False   False
# 4  False  False     False  False  False  False     False  False   False
#
#    height  weight  frame  bp.1s  bp.1d  waist    hip
# 0   False   False  False  False  False  False  False
# 1   False   False  False  False  False  False  False
# 2   False   False  False  False  False  False  False
# 3   False   False  False  False  False  False  False
# 4   False   False  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# id           0
# chol         3
# stab.glu     2
# hdl          1
# ratio        1
# glyhb       13
# location     0
# age          0
# gender       3
# height       5
# weight       1
# frame       12
# bp.1s        5
# bp.1d        5
# waist        2
# hip          2
# dtype: int64

# %%
df["chol"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 373    False
# 374    False
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# 401    False
# 402    False
# Name: chol, Length: 403, dtype: bool

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x107c07320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102474630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a99aa20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10a9cbb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10aa05b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10aa05b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10aa76c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a9e4438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10aae0240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ab1a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ab52390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ab8a400>]], dtype=object)

# %%
df["chol"].hist(bins=100)

# %%
df["weight"].mean()
# Out:
# 177.59203980099502

# %%
df["weight"].mode()
# Out:
# 0    170.0
# dtype: float64

# %%
df["weight"].median()
# Out:
# 172.5

# %%
df.mean()
# Out:
# id          15978.310174
# chol          207.895000
# stab.glu      106.690773
# hdl            50.445274
# ratio           4.521642
# glyhb           5.589769
# height         66.020101
# weight        177.592040
# bp.1s         136.904523
# bp.1d          83.321608
# waist          37.900249
# hip            43.039900
# dtype: float64

# %%
df["gender"].isnull().sum()
# Out:
# 3

# %%
df["gender"].hist()

# %%
df.groupby(["gender"]).agg({'gender':'count'})
# Out:
#         gender
# gender
# female     233
# male       167

# %%
df["gender"].value_counts()
# Out:
# female    233
# male      167
# Name: gender, dtype: int64

# %%
df["gender"].fillna("female", inplace=True)

# %%
df["gender"].isnull().sum()
# Out:
# 0

# %%
df["gender"].value_counts()
# Out:
# female    236
# male      167
# Name: gender, dtype: int64

# %%
#df.to_csv("diabetes_clean.csv")

# %%
df["chol"].isnull().sum()
# Out:
# 3

# %%
df["chol"].hist(bins=50)

# %%
df["chol"].fillna(df["chol"].median(), inplace=True)

# %%
df["chol"].isnull().sum()
# Out:
# 0

# %%
df["chol"].fillna(df["chol"].median()).isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0      82.0  56.0    3.6   4.31  Buckingham  _46  female    62.0
# 1  1001  165.0      97.0  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0      92.0  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0      93.0  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0      90.0  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  waist   hip
# 0   121.0  medium  118.0   59.0   29.0  38.0
# 1   218.0   large  112.0   68.0   46.0  48.0
# 2   256.0   large  190.0   92.0   49.0  57.0
# 3   119.0   large  110.0   50.0   33.0  38.0
# 4   183.0  medium  138.0   80.0   44.0  41.0

# %%
df.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  403.000000  401.000000  402.000000  402.000000
# mean   15978.310174  207.866005  106.690773   50.445274    4.521642
# std    11881.122124   44.369849   53.206852   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb      height      weight       bp.1s       bp.1d       waist  \
# count  390.000000  398.000000  402.000000  398.000000  398.000000  401.000000
# mean     5.589769   66.020101  177.592040  136.904523   83.321608   37.900249
# std      2.242595    3.918515   40.340666   22.741033   13.589227    5.729313
# min      2.680000   52.000000   99.000000   90.000000   48.000000   26.000000
# 25%      4.380000   63.000000  151.000000  121.250000   75.000000   33.000000
# 50%      4.840000   66.000000  172.500000  136.000000   82.000000   37.000000
# 75%      5.600000   69.000000  200.000000  146.750000   90.000000   41.000000
# max     16.110001   76.000000  325.000000  250.000000  124.000000   56.000000
#
#               hip
# count  401.000000
# mean    43.039900
# std      5.656713
# min     30.000000
# 25%     39.000000
# 50%     42.000000
# 75%     46.000000
# max     64.000000

# %%
df.columns
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'location', 'age',
#        'gender', 'height', 'weight', 'frame', 'bp.1s', 'bp.1d', 'waist',
#        'hip'],
#       dtype='object')

# %%
df["age"].dtype
# Out:
# dtype('O')

# %%
df["chol"].dtype
# Out:
# dtype('float64')

# %%
import numpy as np

# %%
df["age"].to_frame().applymap(np.isreal)
# Out:
#        age
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17   False
# 18   False
# 19   False
# 20   False
# 21   False
# 22   False
# 23   False
# 24   False
# 25   False
# 26   False
# 27   False
# 28   False
# 29   False
# ..     ...
# 373  False
# 374  False
# 375  False
# 376  False
# 377  False
# 378  False
# 379  False
# 380  False
# 381  False
# 382  False
# 383  False
# 384  False
# 385  False
# 386  False
# 387  False
# 388  False
# 389  False
# 390  False
# 391  False
# 392  False
# 393  False
# 394  False
# 395  False
# 396  False
# 397  False
# 398  False
# 399  False
# 400  False
# 401  False
# 402  False
#
# [403 rows x 1 columns]

# %%
for val in df["age"]:
    if not str(val).isdigit():
        print(val)
# Out:
# _46
# _45

# %%
for index, row in df.iterrows():
    if not str(row["age"]).isdigit():
        print(index, row["age"])
# Out:
# 0 _46
# 8 _45

# %%
for x in range(0, len(df)):
    
    print(df.iloc(x,)[0])
# Out:
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# ...
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object
# id                1000
# chol               203
# stab.glu            82
# hdl                 56
# ratio              3.6
# glyhb             4.31
# location    Buckingham
# age                _46
# gender          female
# height              62
# weight             121
# frame           medium
# bp.1s              118
# bp.1d               59
# waist               29
# hip                 38
# Name: 0, dtype: object

# %%
len(df)
# Out:
# 403

# %%
df["age"] = df["age"].str.replace("_", "")

# %%
for index, row in df.iterrows():
    if not str(row["age"]).isdigit():
        print(index, row["age"])

# %%
df["age"].dtype
# Out:
# dtype('O')

# %%
df["age"] = df["age"].apply(pd.to_numeric)

# %%
df["age"].dtype
# Out:
# dtype('int64')

# %%
df.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  403.000000  401.000000  402.000000  402.000000
# mean   15978.310174  207.866005  106.690773   50.445274    4.521642
# std    11881.122124   44.369849   53.206852   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb         age      height      weight       bp.1s       bp.1d  \
# count  390.000000  403.000000  398.000000  402.000000  398.000000  398.000000
# mean     5.589769   46.851117   66.020101  177.592040  136.904523   83.321608
# std      2.242595   16.312333    3.918515   40.340666   22.741033   13.589227
# min      2.680000   19.000000   52.000000   99.000000   90.000000   48.000000
# 25%      4.380000   34.000000   63.000000  151.000000  121.250000   75.000000
# 50%      4.840000   45.000000   66.000000  172.500000  136.000000   82.000000
# 75%      5.600000   60.000000   69.000000  200.000000  146.750000   90.000000
# max     16.110001   92.000000   76.000000  325.000000  250.000000  124.000000
#
#             waist         hip
# count  401.000000  401.000000
# mean    37.900249   43.039900
# std      5.729313    5.656713
# min     26.000000   30.000000
# 25%     33.000000   39.000000
# 50%     37.000000   42.000000
# 75%     41.000000   46.000000
# max     56.000000   64.000000
