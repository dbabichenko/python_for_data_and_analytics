# %%
# Import Pandas module
# Import NumPy module
import numpy as np
import pandas as pd

# We will cover data visualization in more details later in the semester.
# For now the only visualization that we'll explore is histograms.
# Histograms are helpful for visually examining distribution of a particular variable

# The following line is a directive that tells matplotlib module to display
# generated graphs inline with the output of your code
# %matplotlib inline 

# Import matplotlib module.  Matplotlib module allows us to generate graphs from data
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
# Import data file into a Pandas dataframe
df = pd.read_csv("../data/video_games.csv")

# Display the first 5 rows of the data
df.head()
# Out:
#    number                            game  release_date  price  \
# 0       1                     Half-Life 2  Nov 16, 2004   9.99
# 1       3          Counter-Strike: Source   Nov 1, 2004   9.99
# 2      21  Counter-Strike: Condition Zero   Mar 1, 2004   9.99
# 3      47         Half-Life 2: Deathmatch   Nov 1, 2004   4.99
# 4      36               Half-Life: Source   Jun 1, 2004   9.99
#
#                      owners developer publisher  average_playtime  \
# 0  10,000,000 .. 20,000,000     Valve     Valve             110.0
# 1  10,000,000 .. 20,000,000     Valve     Valve             236.0
# 2  10,000,000 .. 20,000,000     Valve     Valve              10.0
# 3   5,000,000 .. 10,000,000     Valve     Valve               0.0
# 4    2,000,000 .. 5,000,000     Valve     Valve               0.0
#
#    median_playtime  metascore
# 0             66.0       96.0
# 1            128.0       88.0
# 2              3.0       65.0
# 3              0.0        NaN
# 4              0.0        NaN

# %%
df.dtypes
# Out:
# number                int64
# game                 object
# release_date         object
# price               float64
# owners               object
# developer            object
# publisher            object
# average_playtime    float64
# median_playtime     float64
# metascore           float64
# dtype: object

# %%
# Before cleaning your data or trying to figure out how to analyze it, it is always a
# good idea to understand what your data actually looks like
# describe() function of DataFrame allows us to view basic statistics about our data
df.describe()
# Out:
#              number         price  average_playtime  median_playtime  \
# count  26688.000000  23593.000000      26679.000000     26676.000000
# mean    2904.194170      8.947136          9.057274         5.159732
# std     2377.066421     12.164410        117.938246        68.911476
# min        1.000000      0.490000          0.000000         0.000000
# 25%      821.000000      2.990000          0.000000         0.000000
# 50%     2356.000000      5.990000          0.000000         0.000000
# 75%     4523.250000      9.990000          0.000000         0.000000
# max     8846.000000    595.990000       5670.000000      3293.000000
#
#          metascore
# count  2850.000000
# mean     71.895439
# std      11.017788
# min      20.000000
# 25%      66.000000
# 50%      73.000000
# 75%      80.000000
# max      98.000000

# %%
# Now let's generate histograms for all continuous variables to
# make sure that there are no issues with distributions and/or outliers.
df.hist()
# Out:
# array([[<Axes: title={'center': 'number'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'average_playtime'}>,
#         <Axes: title={'center': 'median_playtime'}>],
#        [<Axes: title={'center': 'metascore'}>, <Axes: >]], dtype=object)

# %%
# Looking at histograms of all variables at the same time is a bit difficult,
# so let's generate a histogram for the variable that we are actually
# interested in examining
df["price"].hist(bins=150)
# Out:
# <Axes: >

# %%
# In Pandas, using query to select a subset of the data is the faster option than 
# using loops to select data
q = "metascore < 80 & metascore > 70"
df_filtered = df.query(q)
df_filtered
# Out:
#        number                                       game  release_date  price  \
# 8          14                            Beyond Divinity  Apr 27, 2004   5.99
# 16         12           Soldiers: Heroes of World War II  Jun 29, 2004   4.99
# 29         11                                  Perimeter  May 21, 2004   3.99
# 30         15                     Warlords Battlecry III  May 17, 2004   9.99
# 31         16                               Men of Valor  Nov 29, 2004   9.99
# ...       ...                                        ...           ...    ...
# 19001     185                            39 Days to Mars  Apr 25, 2018  14.99
# 19002     187                   I Hate Running Backwards  May 22, 2018  14.99
# 19003     188  Leisure Suit Larry - Wet Dreams Don't Dry   Nov 7, 2018  29.99
# 19004     189                           Masters of Anima  Apr 10, 2018  19.99
# 19005     190                                   Sea Dogs  Jan 14, 2018  11.99
#
#                      owners                                     developer  \
# 8      500,000 .. 1,000,000                                Larian Studios
# 16       100,000 .. 200,000                                      Best Way
# 29         20,000 .. 50,000                                       K-D Lab
# 30         20,000 .. 50,000                          Infinite Interactive
# 31         20,000 .. 50,000                                          2015
# ...                     ...                                           ...
# 19001           0 .. 20,000                                It's Anecdotal
# 19002           0 .. 20,000  Binx Interactive, Croteam Incubator, Croteam
# 19003           0 .. 20,000                                    CrazyBunch
# 19004           0 .. 20,000                                Passtech Games
# 19005           0 .. 20,000                                        Akella
#
#                                 publisher  average_playtime  median_playtime  \
# 8                          Larian Studios               0.0              0.0
# 16                       1C Entertainment               0.0              0.0
# 29                       1C Entertainment               0.0              0.0
# 30     Retroism, Enlight Software Limited               0.0              0.0
# 31                             THQ Nordic               0.0              0.0
# ...                                   ...               ...              ...
# 19001                      It's Anecdotal               0.0              0.0
# 19002                    Devolver Digital               0.0              0.0
# 19003              Assemble Entertainment               0.0              0.0
# 19004              Focus Home Interactive               0.0              0.0
# 19005                              Akella               0.0              0.0
#
#        metascore
# 8           73.0
# 16          77.0
# 29          77.0
# 30          73.0
# 31          71.0
# ...          ...
# 19001       71.0
# 19002       71.0
# 19003       71.0
# 19004       71.0
# 19005       71.0
#
# [954 rows x 10 columns]

# %%
# Building a dataframe row by row in Pandas is definitely not the a recommended solution
# if you really want to do something similar, a better solution is to create a list and
# convert the entire list to dataframe.
filtered_list = []
for idx, row in df.iterrows():
    if row['metascore'] < 80 and row['metascore'] > 70:
        filtered_list.append(row.to_dict())
df_filtered_prime = pd.DataFrame(filtered_list)
df_filtered_prime.head()
# Out:
#    number                              game  release_date  price  \
# 0      14                   Beyond Divinity  Apr 27, 2004   5.99
# 1      12  Soldiers: Heroes of World War II  Jun 29, 2004   4.99
# 2      11                         Perimeter  May 21, 2004   3.99
# 3      15            Warlords Battlecry III  May 17, 2004   9.99
# 4      16                      Men of Valor  Nov 29, 2004   9.99
#
#                  owners             developer  \
# 0  500,000 .. 1,000,000        Larian Studios
# 1    100,000 .. 200,000              Best Way
# 2      20,000 .. 50,000               K-D Lab
# 3      20,000 .. 50,000  Infinite Interactive
# 4      20,000 .. 50,000                  2015
#
#                             publisher  average_playtime  median_playtime  \
# 0                      Larian Studios               0.0              0.0
# 1                    1C Entertainment               0.0              0.0
# 2                    1C Entertainment               0.0              0.0
# 3  Retroism, Enlight Software Limited               0.0              0.0
# 4                          THQ Nordic               0.0              0.0
#
#    metascore
# 0       73.0
# 1       77.0
# 2       77.0
# 3       73.0
# 4       71.0

# %%
# Now let's check which values in the dataset are missing/empty
# Note that Pandas treats missing, empty, and null as pretty much the same thing
# isnull() function will render the entire DataFrame with False value in those
# records where the data IS NOT missing, and True where the value IS missing
df.isnull().describe()
# Out:
#        number   game release_date  price owners developer publisher  \
# count   26688  26688        26688  26688  26688     26688     26688
# unique      1      2            1      2      1         2         2
# top     False  False        False  False  False     False     False
# freq    26688  26685        26688  23593  26688     26536     26568
#
#        average_playtime median_playtime metascore
# count             26688           26688     26688
# unique                2               2         2
# top               False           False      True
# freq              26679           26676     23838

# %%
# As you can see, running isnull() on the entire dataframe produces
# too much data and it difficult to examine visually.  To summarize
# which columns have missing data, we can comibine isnull() with sum()

df.isnull().sum()
# Out:
# number                  0
# game                    3
# release_date            0
# price                3095
# owners                  0
# developer             152
# publisher             120
# average_playtime        9
# median_playtime        12
# metascore           23838
# dtype: int64

# %%
# you can get a sub dataframe with all the rows that have at list one null data.

df_nan = df[df.isnull().any(axis=1)]
df_nan
# Out:
#        number                                   game  release_date  price  \
# 3          47                Half-Life 2: Deathmatch   Nov 1, 2004   4.99
# 4          36                      Half-Life: Source   Jun 1, 2004   9.99
# 5          52                                   CS2D  Dec 24, 2004    NaN
# 9          40                      Hitman: Contracts  Apr 20, 2004   8.99
# 12         43  STAR WARS Battlefront (Classic, 2004)  Sep 21, 2004   9.99
# ...       ...                                    ...           ...    ...
# 26683    8842                              Draw Near  Apr 15, 2018    NaN
# 26684    8843                                  Alone   May 1, 2018   0.99
# 26685    8844                              qrth-phyl  Jul 19, 2018   4.99
# 26686    8845                         Guns and Notes  Jan 26, 2018   9.99
# 26687    8846          VANILLA - GARDEN OF JUDGEMENT  Aug 10, 2018  14.99
#
#                         owners               developer  \
# 3      5,000,000 .. 10,000,000                   Valve
# 4       2,000,000 .. 5,000,000                   Valve
# 5       1,000,000 .. 2,000,000         Unreal Software
# 9         500,000 .. 1,000,000      Io-Interactive A/S
# 12          200,000 .. 500,000        Pandemic Studios
# ...                        ...                     ...
# 26683              0 .. 20,000             Omniscience
# 26684              0 .. 20,000      Killed Pixel Games
# 26685              0 .. 20,000                  Verran
# 26686              0 .. 20,000              VR Factory
# 26687              0 .. 20,000  CHARON, Kaoru Nekofuji
#
#                           publisher  average_playtime  median_playtime  \
# 3                             Valve               0.0              0.0
# 4                             Valve               0.0              0.0
# 5                   Unreal Software              16.0             10.0
# 9                Io-Interactive A/S               0.0              0.0
# 12     Lucasfilm, LucasArts, Disney               0.0              0.0
# ...                             ...               ...              ...
# 26683               Taiga Nishimura               0.0              0.0
# 26684            Killed Pixel Games               0.0              0.0
# 26685                        Verran               0.0              0.0
# 26686                    VR Factory               0.0              0.0
# 26687                        CHARON               0.0              0.0
#
#        metascore
# 3            NaN
# 4            NaN
# 5            NaN
# 9            NaN
# 12           NaN
# ...          ...
# 26683        NaN
# 26684        NaN
# 26685        NaN
# 26686        NaN
# 26687        NaN
#
# [24020 rows x 10 columns]

# %%
# Now let's deal with missing values

# Solution 1: Remove rows with empty values
# If there are only a few null values and you know that deleting values will
# not cause adverse effects on your result, remove them from your DataFrame and
# store should be ok. But our case here is not ideal.

print("Missing values before dropping rows: ")
print(df.shape)

print("Missing values after dropping rows: ")
print(df.dropna().shape)
# Out:
# Missing values before dropping rows:
# (26688, 10)
# Missing values after dropping rows:
# (2668, 10)

# %%
# The problem in this case is the metascore column with 23838 missing values.
# Depending on the analysis, we may want to drop the column entirely, or just stick to the
# remaining 2668 rows if we are interested in metascore.

df_no_score = df.drop(columns=["metascore"])
df_score = df.dropna(subset=["metascore"])

# %%
df_score.describe()
# Out:
#             number        price  average_playtime  median_playtime  \
# count  2850.000000  2691.000000       2848.000000      2845.000000
# mean    160.196140    15.904783         46.608497        25.609490
# std     397.049477    10.555365        278.271662       151.974352
# min       1.000000     0.490000          0.000000         0.000000
# 25%      51.000000     9.990000          0.000000         0.000000
# 50%     116.000000    14.990000          0.000000         0.000000
# 75%     200.000000    19.990000          0.000000         0.000000
# max    8251.000000    59.990000       5450.000000      3293.000000
#
#          metascore
# count  2850.000000
# mean     71.895439
# std      11.017788
# min      20.000000
# 25%      66.000000
# 50%      73.000000
# 75%      80.000000
# max      98.000000

# %%
df_score.isnull().sum()
# Out:
# number                0
# game                  1
# release_date          0
# price               159
# owners                0
# developer            11
# publisher             9
# average_playtime      2
# median_playtime       5
# metascore             0
# dtype: int64

# %%
pd.isna(df_score).sum()
# Out:
# number                0
# game                  1
# release_date          0
# price               159
# owners                0
# developer            11
# publisher             9
# average_playtime      2
# median_playtime       5
# metascore             0
# dtype: int64

# %%
df_score.describe()
# Out:
#             number        price  average_playtime  median_playtime  \
# count  2850.000000  2691.000000       2848.000000      2845.000000
# mean    160.196140    15.904783         46.608497        25.609490
# std     397.049477    10.555365        278.271662       151.974352
# min       1.000000     0.490000          0.000000         0.000000
# 25%      51.000000     9.990000          0.000000         0.000000
# 50%     116.000000    14.990000          0.000000         0.000000
# 75%     200.000000    19.990000          0.000000         0.000000
# max    8251.000000    59.990000       5450.000000      3293.000000
#
#          metascore
# count  2850.000000
# mean     71.895439
# std      11.017788
# min      20.000000
# 25%      66.000000
# 50%      73.000000
# 75%      80.000000
# max      98.000000

# %%
df_score[df_score.isnull().any(axis=1)].sample(10)
# Out:
#       number                                            game  release_date  \
# 4011      62                                     Card Hunter  Jul 13, 2015
# 2095      97                                   Poker Night 2  Apr 26, 2013
# 1624      83                             Stronghold Kingdoms  Feb 27, 2012
# 2332     203                                    Two Brothers   Dec 3, 2013
# 1494     108                             YOU DON’T KNOW JACK   Feb 8, 2011
# 2602      23                                         Outland  Sep 29, 2014
# 1940     183                          Fray: Reloaded Edition  Jun 19, 2012
# 4551     270  MISSING: An Interactive Thriller - Episode One  May 25, 2015
# 1599      11                    The Lord of the Rings Online   Jun 6, 2012
# 7674     344                         Krai Mira: Extended Cut  Jul 11, 2016
#
#       price                  owners                  developer  \
# 4011    NaN    500,000 .. 1,000,000                Blue Manchu
# 2095    NaN    500,000 .. 1,000,000             Telltale Games
# 1624    NaN  1,000,000 .. 2,000,000            FireFly Studios
# 2332    NaN       50,000 .. 100,000               Ackk Studios
# 1494    NaN             0 .. 20,000                Jellyvision
# 2602    NaN  1,000,000 .. 2,000,000                Housemarque
# 1940    NaN             0 .. 20,000                Brain Candy
# 4551    NaN       50,000 .. 100,000               Zandel Media
# 1599    NaN  2,000,000 .. 5,000,000  Standing Stone Games, LLC
# 7674   3.99        20,000 .. 50,000            TallTech studio
#
#                       publisher  average_playtime  median_playtime  metascore
# 4011                Blue Manchu               0.0              0.0       80.0
# 2095             Telltale Games               0.0              0.0       75.0
# 1624            FireFly Studios               0.0              0.0       75.0
# 2332               Ackk Studios               0.0              0.0       57.0
# 1494               Nordic Games               0.0              0.0       71.0
# 2602                Housemarque               0.0              0.0       83.0
# 1940                Brain Candy               0.0              0.0       27.0
# 4551               Zandel Media               0.0              0.0       63.0
# 1599  Standing Stone Games, LLC               0.0              0.0       86.0
# 7674                        NaN               0.0              0.0       50.0

# %%
# Let's generate a density plot
df_score["price"].hist(bins=50)
# Out:
# <Axes: >

# %%
# Solution 2: Fill missing values with a mean or medianvalue of a given column

# Find the mean
df_score["price"].median()
# Out:
# np.float64(14.99)

# %%
# Fill missing values with a mean (average) value of a given column
# Note the inplace=True parameter - that means that we are overwriting the data
# in the existing dataset
df_no_score["price"].fillna(df_no_score["price"].median(), inplace=True)
df_no_score.sample(10)
# Out:
# /tmp/ipykernel_14613/3962888673.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_no_score["price"].fillna(df_no_score["price"].median(), inplace=True)
#        number                                game  release_date  price  \
# 17844       6               MONSTER HUNTER: WORLD   Aug 9, 2018  59.99
# 17539    6500                                Cuco  Sep 29, 2017   0.99
# 15525    4028            Fighting Fantasy Legends  Jul 27, 2017   6.99
# 16165    4832                        Black Mirror  Nov 28, 2017  29.99
# 20197    1608                       Ancient Tower  Sep 10, 2018   9.99
# 2767      277                      Spacebase DF-9  Oct 27, 2014   9.99
# 9784     2604  Push The Crate: Remastered Edition  Jul 12, 2016   1.99
# 4120      269                          Party Hard  Aug 25, 2015   9.99
# 9095     1557                               GiAnt   Aug 2, 2016   5.99
# 15933    4525         Elderine: Dreams to Destiny   Apr 1, 2017   3.99
#
#                         owners                developer  \
# 17844  5,000,000 .. 10,000,000         CAPCOM Co., Ltd.
# 17539              0 .. 20,000                  Yah_Shi
# 15525              0 .. 20,000              Nomad Games
# 16165              0 .. 20,000                 KING Art
# 20197              0 .. 20,000            Carlo Monzini
# 2767        200,000 .. 500,000  Double Fine Productions
# 9784               0 .. 20,000        West Forest Games
# 4120        200,000 .. 500,000     Pinokl Games, Kverta
# 9095               0 .. 20,000       Wreck Tangle Games
# 15933              0 .. 20,000      Black Alchemy Games
#
#                      publisher  average_playtime  median_playtime
# 17844         CAPCOM Co., Ltd.             914.0            286.0
# 17539              Rhino Games               0.0              0.0
# 15525          Asmodee Digital               0.0              0.0
# 16165               THQ Nordic               0.0              0.0
# 20197            Carlo Monzini               0.0              0.0
# 2767   Double Fine Productions               0.0              0.0
# 9784         West Forest Games               0.0              0.0
# 4120                 tinyBuild               0.0              0.0
# 9095        Wreck Tangle Games               0.0              0.0
# 15933      Black Alchemy Games               0.0              0.0

# %%
# but actually, it's better for us just drop all rows with missing values
df_score.dropna(subset=["price", "average_playtime", "median_playtime"], inplace=True)
df_score.sample(10)
# Out:
# /tmp/ipykernel_14613/1837140305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_score.dropna(subset=["price", "average_playtime", "median_playtime"], inplace=True)
#        number                                           game  release_date  \
# 17844       6                          MONSTER HUNTER: WORLD   Aug 9, 2018
# 18168      56  The Legend of Heroes: Trails of Cold Steel II  Feb 14, 2018
# 1112      112                                  Rocket Knight  May 11, 2010
# 4296       54                           The Age of Decadence  Oct 14, 2015
# 3228      104                      Shadows: Heretic Kingdoms  Nov 20, 2014
# 1258       49                                           RAGE   Oct 3, 2011
# 1644       38              Lone Survivor: The Director's Cut  Apr 23, 2012
# 1686       35                 LEGO Batman 2: DC Super Heroes  Jun 22, 2012
# 1380      145                   Disciples III - Resurrection  Oct 11, 2011
# 1704       73                 Insanely Twisted Shadow Planet  Apr 17, 2012
#
#        price                   owners                  developer  \
# 17844  59.99  5,000,000 .. 10,000,000           CAPCOM Co., Ltd.
# 18168  39.99        50,000 .. 100,000               Nihon Falcom
# 1112   14.99              0 .. 20,000             Climax Studios
# 4296   14.99       100,000 .. 200,000          Iron Tower Studio
# 3228   39.99         20,000 .. 50,000                 Games Farm
# 1258    9.99   1,000,000 .. 2,000,000                id Software
# 1644   14.99     500,000 .. 1,000,000               Jasper Byrne
# 1686   19.99       200,000 .. 500,000                   TT Games
# 1380   14.99       100,000 .. 200,000               Akella, .dat
# 1704   14.99       200,000 .. 500,000  Shadow Planet Productions
#
#                                                publisher  average_playtime  \
# 17844                                   CAPCOM Co., Ltd.             914.0
# 18168                   XSEED Games, Marvelous USA, Inc.               0.0
# 1112   Konami Digital Entertainment, Inc., Konami Dig...               0.0
# 4296                                   Iron Tower Studio               0.0
# 3228                               Kalypso Media Digital               0.0
# 1258                                  Bethesda Softworks               0.0
# 1644                                     Superflat Games               0.0
# 1686              Warner Bros. Interactive Entertainment               0.0
# 1380                               Kalypso Media Digital               0.0
# 1704                                   Xbox Game Studios               0.0
#
#        median_playtime  metascore
# 17844            286.0       88.0
# 18168              0.0       81.0
# 1112               0.0       63.0
# 4296               0.0       81.0
# 3228               0.0       74.0
# 1258               0.0       79.0
# 1644               0.0       81.0
# 1686               0.0       81.0
# 1380               0.0       63.0
# 1704               0.0       76.0

# %% [markdown]
# ---

# %%
# Now let's figure out how to deal with discrete values
# Gender is a non-numeric (discrete) column, so we cannot use
# mean, median, or mode to replace the missing value
# A (somewhat) acceptable solution is to replace missing values with
# the most frequently occurring value

# Let's find out the number of missing values in the "gender" column
df_score["publisher"].isnull().sum()
# Out:
# np.int64(7)

# %%
df_score["publisher"].value_counts()
# Out:
# publisher
# Ubisoft                            82
# THQ Nordic                         53
# Devolver Digital                   47
# Square Enix                        44
# Paradox Interactive                43
#                                    ..
# MichaelArts                         1
# Groovy Milk, GrabTheGames           1
# CyberCoconut, White Manager srl     1
# Para                                1
# Abyssal Arts Ltd.                   1
# Name: count, Length: 1132, dtype: int64

# %%
# You can use Pandas' groupby() function to group by and aggregate your DataFrame
# by a particular column or a set of columns

# Let's group by gender and aggregate by mean and count
df_score.groupby(["publisher"]).agg({"publisher": "count"})
# Out:
#                                      publisher
# publisher
# 10tons Ltd                                   4
# 11 bit studios                               9
# 11Sheep                                      1
# 13AM Shipping Solutions, 13AM Games          1
# 17-BIT                                       2
# ...                                        ...
# nextReality Games                            1
# teedoubleuGAMES                              1
# tinyBuild                                   13
# tinyBuild Games                              1
# tobyfox                                      1
#
# [1132 rows x 1 columns]

# %%
# This doesn't look that nice, both columns are named publisher. It will be a nightmare to
# use this dataframe to do any further analysis.

# let's make it prettier:
df_publisher = df_score.groupby(["publisher"]).agg(
    count=pd.NamedAgg(column="publisher", aggfunc="count")
).reset_index()
df_publisher.sort_values('count', ascending=False)
# Out:
#                    publisher  count
# 1016                 Ubisoft     82
# 932               THQ Nordic     53
# 271         Devolver Digital     47
# 890              Square Enix     44
# 713      Paradox Interactive     43
# ...                      ...    ...
# 1107          Zombie Studios      1
# 17                 2x2 Games      1
# 15    2K, Missing Link Games      1
# 11           2K, Aspyr (Mac)      1
# 10         2K, Aspyr (Linux)      1
#
# [1132 rows x 2 columns]

# %%
# Now that we know that "Ubisoft" occurs more frequently...
df_score_ubi = df_score["publisher"].fillna("Ubisoft")
df_score_ubi
# Out:
# 0                                   Valve
# 1                                   Valve
# 2                                   Valve
# 6                        Epic Games, Inc.
# 7                             id Software
#                        ...
# 21446    Dark Illusions Entertainment LLC
# 23311                 Neko Climax Studios
# 23367                           RewindApp
# 26038                       SmallSqurriel
# 26149                           RewindApp
# Name: publisher, Length: 2686, dtype: object

# %%
df_score = df_score.dropna()
df_score
# Out:
#        number                                             game  release_date  \
# 0           1                                      Half-Life 2  Nov 16, 2004
# 1           3                           Counter-Strike: Source   Nov 1, 2004
# 2          21                   Counter-Strike: Condition Zero   Mar 1, 2004
# 6           2  Unreal Tournament 2004: Editor's Choice Edition  Mar 16, 2004
# 7           4                                           DOOM 3   Aug 3, 2004
# ...       ...                                              ...           ...
# 21446    2972                                      SUPER KINKY   Jul 6, 2018
# 23311    5052                       DEEP SPACE WAIFU: NEKOMIMI  Dec 18, 2018
# 23367    5133                                      Hentai Dojo  Aug 24, 2018
# 26038    8118                    Story of Eve - A Hero's Study  Oct 16, 2018
# 26149    8251                              Hentai Case Opening  Sep 27, 2018
#
#        price                    owners                         developer  \
# 0       9.99  10,000,000 .. 20,000,000                             Valve
# 1       9.99  10,000,000 .. 20,000,000                             Valve
# 2       9.99  10,000,000 .. 20,000,000                             Valve
# 6      14.99      500,000 .. 1,000,000                  Epic Games, Inc.
# 7       4.99      500,000 .. 1,000,000                       id Software
# ...      ...                       ...                               ...
# 21446   1.99               0 .. 20,000  Dark Illusions Entertainment LLC
# 23311   1.99               0 .. 20,000               Neko Climax Studios
# 23367   0.49               0 .. 20,000                         RewindApp
# 26038   2.99               0 .. 20,000                     SmallSqurriel
# 26149   0.99               0 .. 20,000                         RewindApp
#
#                               publisher  average_playtime  median_playtime  \
# 0                                 Valve             110.0             66.0
# 1                                 Valve             236.0            128.0
# 2                                 Valve              10.0              3.0
# 6                      Epic Games, Inc.               0.0              0.0
# 7                           id Software               0.0              0.0
# ...                                 ...               ...              ...
# 21446  Dark Illusions Entertainment LLC               0.0              0.0
# 23311               Neko Climax Studios               0.0              0.0
# 23367                         RewindApp               0.0              0.0
# 26038                     SmallSqurriel               0.0              0.0
# 26149                         RewindApp               0.0              0.0
#
#        metascore
# 0           96.0
# 1           88.0
# 2           65.0
# 6           93.0
# 7           87.0
# ...          ...
# 21446       70.0
# 23311       98.0
# 23367       65.0
# 26038       87.0
# 26149       63.0
#
# [2668 rows x 10 columns]

# %%
# after dropping rows with missing values, the indexes are no longer sequential, there are gaps
# let's reset the index
df_score.reset_index(drop=True, inplace=True)
df_score
# Out:
#       number                                             game  release_date  \
# 0          1                                      Half-Life 2  Nov 16, 2004
# 1          3                           Counter-Strike: Source   Nov 1, 2004
# 2         21                   Counter-Strike: Condition Zero   Mar 1, 2004
# 3          2  Unreal Tournament 2004: Editor's Choice Edition  Mar 16, 2004
# 4          4                                           DOOM 3   Aug 3, 2004
# ...      ...                                              ...           ...
# 2663    2972                                      SUPER KINKY   Jul 6, 2018
# 2664    5052                       DEEP SPACE WAIFU: NEKOMIMI  Dec 18, 2018
# 2665    5133                                      Hentai Dojo  Aug 24, 2018
# 2666    8118                    Story of Eve - A Hero's Study  Oct 16, 2018
# 2667    8251                              Hentai Case Opening  Sep 27, 2018
#
#       price                    owners                         developer  \
# 0      9.99  10,000,000 .. 20,000,000                             Valve
# 1      9.99  10,000,000 .. 20,000,000                             Valve
# 2      9.99  10,000,000 .. 20,000,000                             Valve
# 3     14.99      500,000 .. 1,000,000                  Epic Games, Inc.
# 4      4.99      500,000 .. 1,000,000                       id Software
# ...     ...                       ...                               ...
# 2663   1.99               0 .. 20,000  Dark Illusions Entertainment LLC
# 2664   1.99               0 .. 20,000               Neko Climax Studios
# 2665   0.49               0 .. 20,000                         RewindApp
# 2666   2.99               0 .. 20,000                     SmallSqurriel
# 2667   0.99               0 .. 20,000                         RewindApp
#
#                              publisher  average_playtime  median_playtime  \
# 0                                Valve             110.0             66.0
# 1                                Valve             236.0            128.0
# 2                                Valve              10.0              3.0
# 3                     Epic Games, Inc.               0.0              0.0
# 4                          id Software               0.0              0.0
# ...                                ...               ...              ...
# 2663  Dark Illusions Entertainment LLC               0.0              0.0
# 2664               Neko Climax Studios               0.0              0.0
# 2665                         RewindApp               0.0              0.0
# 2666                     SmallSqurriel               0.0              0.0
# 2667                         RewindApp               0.0              0.0
#
#       metascore
# 0          96.0
# 1          88.0
# 2          65.0
# 3          93.0
# 4          87.0
# ...         ...
# 2663       70.0
# 2664       98.0
# 2665       65.0
# 2666       87.0
# 2667       63.0
#
# [2668 rows x 10 columns]

# %% [markdown]
# ---

# %%
# Let's check to make sure that the data in a given column is all numeric
df_score.map(np.isreal)
# Out:
#       number   game  release_date  price  owners  developer  publisher  \
# 0       True  False         False   True   False      False      False
# 1       True  False         False   True   False      False      False
# 2       True  False         False   True   False      False      False
# 3       True  False         False   True   False      False      False
# 4       True  False         False   True   False      False      False
# ...      ...    ...           ...    ...     ...        ...        ...
# 2663    True  False         False   True   False      False      False
# 2664    True  False         False   True   False      False      False
# 2665    True  False         False   True   False      False      False
# 2666    True  False         False   True   False      False      False
# 2667    True  False         False   True   False      False      False
#
#       average_playtime  median_playtime  metascore
# 0                 True             True       True
# 1                 True             True       True
# 2                 True             True       True
# 3                 True             True       True
# 4                 True             True       True
# ...                ...              ...        ...
# 2663              True             True       True
# 2664              True             True       True
# 2665              True             True       True
# 2666              True             True       True
# 2667              True             True       True
#
# [2668 rows x 10 columns]

# %%
# Now let's check the owners column:
# It looks like an range of estimations with upper and lower bounds
# But it is stored as a string, which does not make it easy to do calculations on it

df_score["owners"].to_frame()
# Out:
#                         owners
# 0     10,000,000 .. 20,000,000
# 1     10,000,000 .. 20,000,000
# 2     10,000,000 .. 20,000,000
# 3         500,000 .. 1,000,000
# 4         500,000 .. 1,000,000
# ...                        ...
# 2663               0 .. 20,000
# 2664               0 .. 20,000
# 2665               0 .. 20,000
# 2666               0 .. 20,000
# 2667               0 .. 20,000
#
# [2668 rows x 1 columns]

# %%
# Let's convert the owners column to two numeric columns: owners_lower and owners_upper
df_score["owners_lower"] = df_score["owners"].apply(
    lambda x: int(x.split("..")[0].strip().replace(",", ""))
)
df_score["owners_upper"] = df_score["owners"].apply(
    lambda x: x.split("..")[1].strip().replace(",", "")
)
df_score.drop(columns=["owners"], inplace=True)
df_score.head()
# Out:
#    number                                             game  release_date  \
# 0       1                                      Half-Life 2  Nov 16, 2004
# 1       3                           Counter-Strike: Source   Nov 1, 2004
# 2      21                   Counter-Strike: Condition Zero   Mar 1, 2004
# 3       2  Unreal Tournament 2004: Editor's Choice Edition  Mar 16, 2004
# 4       4                                           DOOM 3   Aug 3, 2004
#
#    price         developer         publisher  average_playtime  \
# 0   9.99             Valve             Valve             110.0
# 1   9.99             Valve             Valve             236.0
# 2   9.99             Valve             Valve              10.0
# 3  14.99  Epic Games, Inc.  Epic Games, Inc.               0.0
# 4   4.99       id Software       id Software               0.0
#
#    median_playtime  metascore  owners_lower owners_upper
# 0             66.0       96.0      10000000     20000000
# 1            128.0       88.0      10000000     20000000
# 2              3.0       65.0      10000000     20000000
# 3              0.0       93.0        500000      1000000
# 4              0.0       87.0        500000      1000000

# %%
df_score[['average_playtime','metascore','owners_lower', 'price']].describe()
# Out:
#        average_playtime    metascore  owners_lower       price
# count       2668.000000  2668.000000  2.668000e+03  2668.00000
# mean          39.564093    71.902924  3.811844e+05    15.94078
# std          222.266015    10.980773  1.365027e+06    10.57736
# min            0.000000    20.000000  0.000000e+00     0.49000
# 25%            0.000000    66.000000  2.000000e+04     9.99000
# 50%            0.000000    73.000000  1.000000e+05    14.99000
# 75%            0.000000    80.000000  2.000000e+05    19.99000
# max         4461.000000    98.000000  5.000000e+07    59.99000

# %%
df_score[['average_playtime','metascore','owners_lower', 'price']].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'average_playtime'}>,
#         <Axes: title={'center': 'metascore'}>],
#        [<Axes: title={'center': 'owners_lower'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)
